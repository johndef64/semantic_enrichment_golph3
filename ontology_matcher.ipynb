# %% [markdown]
# # Semantic Enrichment of GOLPH3 Gene Dataset
#
# ## Description
#
# This project aims to enrich genomic and phenotypic datasets extracted from Ensembl's datamart through semantic enhancement techniques. The target dataset focuses on the GOLPH3 gene and includes both genomic and phenotypic data points.
#
# The GOLPH3 gene encodes an adapter essential for the recycling of Golgi glycosylation enzymes involved in the pathway of glycosphingolipid (GLS) production. Overexpression of GOLPH3 leads to chemoresistance in tumor cells ([Rizzo et al.](https://pubmed.ncbi.nlm.nih.gov/33749896/)). This project aims to uncover additional disease pathways in which the GOLPH3 gene may be involved through a knowledge-driven research approach based on disease ontologies.
#
#
# The phenotypic data within the dataset has been enriched using two disease ontologies: DOID ([Human Disease Ontology](https://bioportal.bioontology.org/ontologies/DOID)) and MONDO ([Mondo Disease Ontology](https://bioportal.bioontology.org/ontologies/MONDO)). An ontology matcher was developed to facilitate this process. This matcher searches for matches within all synonyms of the ontology classes and appends the IRI (Internationalized Resource Identifier) class ID to the original dataset.
#
# The semantic enrichment of the dataset focusing on the GOLPH3 gene involved cross-linking phenotypic data extracted from Ensembl with disease ontology terms using the DOID and MONDO ontologies. This approach enhances data interoperability and adherence to FAIR principles by appending Internationalized Resource Identifier (IRI) class IDs to the dataset, thereby enabling more efficient data integration and retrieval.
#
#
# ### Key Features
# - **Semantic Enrichment**: Enriches phenotypic data using Human Disease Ontology (DOID) and Mondo Disease Ontology (MONDO).
# - **Ontology Matcher**: Custom-built tool for matching dataset terms with ontology synonyms and appending Internationalized Resource Identifiers (IRIs) for enhanced data linkage.
# - **Data Integration**: Facilitates efficient data integration and retrieval through semantic annotations.
#
#
# [Here is a link to the project repository](https://github.com/your-repo)
#
# ### Contact
# For questions or contributions, please contact [giovannimaria.defilippis@unina.it].

# %% [markdown]
# # Import requirements

# %%
import os
import csv
import gdown
import requests
import pandas as pd


if 'data' not in os.getcwd():
    if not os.path.exists('data'):
        os.makedirs('data')

    os.chdir('data/')

# %% [markdown]
# # Bio-Dataset:: Ensembl Gine-GOLPH3 features

# %%
# %%time
# Define the Biomart server URL and dataset (Human)
url = 'http://www.ensembl.org/biomart/martservice'
dataset = 'hsapiens_gene_ensembl'

# Define the XML query for the gene GOLPH3
xml_query = """
<Query virtualSchemaName = "default" formatter = "TSV" header = "1" uniqueRows = "1" count = "" datasetConfigVersion = "0.6">
    <Dataset name = "{}" interface = "default">
        <Filter name="hgnc_symbol" value="GOLPH3"/>
        <Attribute name="ensembl_gene_id"/>
        <Attribute name="ensembl_gene_id_version"/>
        <Attribute name="ensembl_peptide_id"/>
        <Attribute name="ensembl_peptide_id_version"/>
        <Attribute name="description"/>
        <Attribute name="chromosome_name"/>
        <Attribute name="start_position"/>
        <Attribute name="end_position"/>
        <Attribute name="strand"/>
        <Attribute name="band"/>
        <Attribute name="external_gene_name"/>
        <Attribute name="external_gene_source"/>
        <Attribute name="percentage_gene_gc_content"/>
        <Attribute name="gene_biotype"/>
        <Attribute name="source"/>
        <Attribute name="version"/>
        <Attribute name="peptide_version"/>
        <Attribute name="external_synonym"/>
        <Attribute name="phenotype_description"/>
        <Attribute name="source_name"/>
        <Attribute name="study_external_id"/>
        <Attribute name="strain_name"/>
        <Attribute name="strain_gender"/>
        <Attribute name="p_value"/>
    </Dataset>
</Query>
""".format(dataset)

# Send the request to the Biomart server
response = requests.post(url, data={'query': xml_query})

# %%
from io import StringIO
# Assuming 'response.text' contains the data in some delimited format
data = response.text
data_io = StringIO(data)
ds = pd.read_table(data_io)
new_col_names = ['ensembl_gene_id', 'ensembl_gene_id_version', 'ensembl_peptide_id',
                 'ensembl_peptide_id_version', 'description', 'chromosome_name',
                 'start_position', 'end_position', 'strand', 'band',
                 'external_gene_name', 'external_gene_source',
                 'percentage_gene_gc_content', 'gene_biotype', 'source', 'version',
                 'peptide_version', 'external_synonym', 'phenotype_description',
                 'source_name', 'study_external_id', 'strain_name', 'strain_gender',
                 'p_value']
# Set the new column names to the DataFrame
ds.columns = new_col_names
ds.to_csv('emsembl_golph3_dataset.csv')
ds
# Out:
#      ensembl_gene_id ensembl_gene_id_version ensembl_peptide_id  \
# 0    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 1    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 2    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 3    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 4    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# ..               ...                     ...                ...
# 451  ENSG00000113384      ENSG00000113384.14                NaN
# 452  ENSG00000113384      ENSG00000113384.14                NaN
# 453  ENSG00000113384      ENSG00000113384.14                NaN
# 454  ENSG00000113384      ENSG00000113384.14                NaN
# 455  ENSG00000113384      ENSG00000113384.14                NaN
#
#     ensembl_peptide_id_version  \
# 0            ENSP00000265070.6
# 1            ENSP00000265070.6
# 2            ENSP00000265070.6
# 3            ENSP00000265070.6
# 4            ENSP00000265070.6
# ..                         ...
# 451                        NaN
# 452                        NaN
# 453                        NaN
# 454                        NaN
# 455                        NaN
#
#                                            description  chromosome_name  \
# 0    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 1    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 2    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 3    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 4    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# ..                                                 ...              ...
# 451  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 452  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 453  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 454  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 455  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
#
#      start_position  end_position  strand   band  ...          source version  \
# 0          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 1          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 2          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 3          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 4          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# ..              ...           ...     ...    ...  ...             ...     ...
# 451        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 452        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 453        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 454        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 455        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
#
#      peptide_version external_synonym  \
# 0                6.0            GOPP1
# 1                6.0            GOPP1
# 2                6.0            GOPP1
# 3                6.0            GOPP1
# 4                6.0            GOPP1
# ..               ...              ...
# 451              NaN            VPS74
# 452              NaN            VPS74
# 453              NaN            VPS74
# 454              NaN            VPS74
# 455              NaN            VPS74
#
#                                  phenotype_description         source_name  \
# 0              Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census
# 1                               Hepatobiliary Neoplasm  Cancer Gene Census
# 2                                                   ND  Cancer Gene Census
# 3    Ovarian Endometrioid Adenocarcinoma with Squam...  Cancer Gene Census
# 4                               Uterine Carcinosarcoma  Cancer Gene Census
# ..                                                 ...                 ...
# 451                                     skin carcinoma  Cancer Gene Census
# 452                          Small cell lung carcinoma  Cancer Gene Census
# 453                                soft tissue sarcoma  Cancer Gene Census
# 454                       squamous cell lung carcinoma  Cancer Gene Census
# 455                                  thyroid carcinoma  Cancer Gene Census
#
#      study_external_id strain_name strain_gender p_value
# 0                  NaN         NaN           NaN     NaN
# 1                  NaN         NaN           NaN     NaN
# 2                  NaN         NaN           NaN     NaN
# 3                  NaN         NaN           NaN     NaN
# 4                  NaN         NaN           NaN     NaN
# ..                 ...         ...           ...     ...
# 451                NaN         NaN           NaN     NaN
# 452                NaN         NaN           NaN     NaN
# 453                NaN         NaN           NaN     NaN
# 454                NaN         NaN           NaN     NaN
# 455                NaN         NaN           NaN     NaN
#
# [456 rows x 24 columns]

# %% [markdown]
# ## Import Dataset

# %%
# load dataset
ds_name = 'emsembl_golph3_dataset'#'ensemble_gene_features_entrez64083_golph3'
ds = pd.read_csv(ds_name+'.csv', index_col=0)
ds
# Out:
#      ensembl_gene_id ensembl_gene_id_version ensembl_peptide_id  \
# 0    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 1    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 2    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 3    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 4    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# ..               ...                     ...                ...
# 451  ENSG00000113384      ENSG00000113384.14                NaN
# 452  ENSG00000113384      ENSG00000113384.14                NaN
# 453  ENSG00000113384      ENSG00000113384.14                NaN
# 454  ENSG00000113384      ENSG00000113384.14                NaN
# 455  ENSG00000113384      ENSG00000113384.14                NaN
#
#     ensembl_peptide_id_version  \
# 0            ENSP00000265070.6
# 1            ENSP00000265070.6
# 2            ENSP00000265070.6
# 3            ENSP00000265070.6
# 4            ENSP00000265070.6
# ..                         ...
# 451                        NaN
# 452                        NaN
# 453                        NaN
# 454                        NaN
# 455                        NaN
#
#                                            description  chromosome_name  \
# 0    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 1    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 2    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 3    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 4    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# ..                                                 ...              ...
# 451  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 452  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 453  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 454  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 455  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
#
#      start_position  end_position  strand   band  ...          source version  \
# 0          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 1          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 2          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 3          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 4          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# ..              ...           ...     ...    ...  ...             ...     ...
# 451        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 452        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 453        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 454        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 455        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
#
#      peptide_version external_synonym  \
# 0                6.0            GOPP1
# 1                6.0            GOPP1
# 2                6.0            GOPP1
# 3                6.0            GOPP1
# 4                6.0            GOPP1
# ..               ...              ...
# 451              NaN            VPS74
# 452              NaN            VPS74
# 453              NaN            VPS74
# 454              NaN            VPS74
# 455              NaN            VPS74
#
#                                  phenotype_description         source_name  \
# 0              Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census
# 1                               Hepatobiliary Neoplasm  Cancer Gene Census
# 2                                                   ND  Cancer Gene Census
# 3    Ovarian Endometrioid Adenocarcinoma with Squam...  Cancer Gene Census
# 4                               Uterine Carcinosarcoma  Cancer Gene Census
# ..                                                 ...                 ...
# 451                                     skin carcinoma  Cancer Gene Census
# 452                          Small cell lung carcinoma  Cancer Gene Census
# 453                                soft tissue sarcoma  Cancer Gene Census
# 454                       squamous cell lung carcinoma  Cancer Gene Census
# 455                                  thyroid carcinoma  Cancer Gene Census
#
#      study_external_id strain_name strain_gender p_value
# 0                  NaN         NaN           NaN     NaN
# 1                  NaN         NaN           NaN     NaN
# 2                  NaN         NaN           NaN     NaN
# 3                  NaN         NaN           NaN     NaN
# 4                  NaN         NaN           NaN     NaN
# ..                 ...         ...           ...     ...
# 451                NaN         NaN           NaN     NaN
# 452                NaN         NaN           NaN     NaN
# 453                NaN         NaN           NaN     NaN
# 454                NaN         NaN           NaN     NaN
# 455                NaN         NaN           NaN     NaN
#
# [456 rows x 24 columns]

# %% [markdown]
# # Import Bio Ontologies

# %% [markdown]
# ## Download DOID
# Source Dataset :: https://data.bioontology.org/ontologies/DOID/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb&download_format=csv

# %%
import gdown
import gzip
import shutil

# The URL to download the CSV file
url = "https://data.bioontology.org/ontologies/DOID/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb&download_format=csv"

# The path where the file will be saved
output = "DOID.gz"
extracted_file = "DOID.csv"

# Download the file
gdown.download(url, output, quiet=False)

# Extract the .gz file
with gzip.open(output, 'rb') as f_in:
    with open(extracted_file, 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
        
# Delete the .gz file
os.remove(output)
# Out:
# Downloading...
# From: https://data.bioontology.org/ontologies/DOID/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb&download_format=csv
# To: G:\Altri computer\Horizon\horizon_workspace\projects\work\semantics\ontology\onto_gene_disease_analysis\data\DOID.gz
# 100%|██████████| 1.82M/1.82M [00:05<00:00, 329kB/s]

# %% [markdown]
# ## Import DOID

# %%
# load csv ontology
doid = pd.read_csv('DOID.csv', low_memory=False)
onto_label = 'DOID'
onto = doid
onto
# Out:
#                                             Class ID  \
# 0           http://purl.obolibrary.org/obo/DOID_3412
# 1      http://purl.obolibrary.org/obo/UBERON_0009623
# 2           http://purl.obolibrary.org/obo/DOID_1204
# 3          http://purl.obolibrary.org/obo/DOID_12040
# 4          http://purl.obolibrary.org/obo/DOID_12043
# ...                                              ...
# 18653       http://purl.obolibrary.org/obo/DOID_8080
# 18654       http://purl.obolibrary.org/obo/DOID_9878
# 18655      http://purl.obolibrary.org/obo/MIM_226400
# 18656       http://purl.obolibrary.org/obo/DOID_3705
# 18657       http://purl.obolibrary.org/obo/DOID_3953
#
#                                          Preferred Label  \
# 0                   obsolete infectious canine hepatitis
# 1                                      spinal nerve root
# 2      obsolete arthropathy due to hypersensitivity r...
# 3                        obsolete immune hydrops fetalis
# 4                     kernicterus due to isoimmunization
# ...                                                  ...
# 18653  obsolete ovarian mucinous cystic tumor associa...
# 18654  obsolete Excessive vomiting starting after 22 ...
# 18655  susceptibility to epidermodysplasia verrucifor...
# 18656                      fallopian tube mucinous tumor
# 18657                               adrenal gland cancer
#
#                                                 Synonyms  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Arthropathy associated with hypersensitivity r...
# 3      Hydrops fetalis due to isoimmunization [dup] (...
# 4                                                    NaN
# ...                                                  ...
# 18653                                                NaN
# 18654              antepartum late vomiting of pregnancy
# 18655                                                NaN
# 18656                                                NaN
# 18657  tumor of the Adrenal gland|neoplasm of adrenal...
#
#                                              Definitions  Obsolete  CUI  \
# 0      A viral infectious disease that involves necro...      True  NaN
# 1                                                    NaN     False  NaN
# 2                                                    NaN      True  NaN
# 3                                                    NaN      True  NaN
# 4                                                    NaN     False  NaN
# ...                                                  ...       ...  ...
# 18653                                                NaN      True  NaN
# 18654                                                NaN      True  NaN
# 18655                                                NaN     False  NaN
# 18656  A fallopian tube benign neoplasm that produces...     False  NaN
# 18657  An endocrine gland cancer located_in the adren...     False  NaN
#
#        Semantic Types                                            Parents  \
# 0                 NaN                                                NaN
# 1                 NaN      http://purl.obolibrary.org/obo/UBERON_0002211
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN           http://purl.obolibrary.org/obo/DOID_2383
# ...               ...                                                ...
# 18653             NaN                                                NaN
# 18654             NaN                                                NaN
# 18655             NaN          http://purl.obolibrary.org/obo/MIM_000000
# 18656             NaN        http://purl.obolibrary.org/obo/DOID_0060111
# 18657             NaN  http://purl.obolibrary.org/obo/DOID_9553|http:...
#
#       adjacent to  auto-generated-by  ...  saved-by  \
# 0             NaN                NaN  ...       NaN
# 1             NaN                NaN  ...       NaN
# 2             NaN                NaN  ...       NaN
# 3             NaN                NaN  ...       NaN
# 4             NaN                NaN  ...       NaN
# ...           ...                ...  ...       ...
# 18653         NaN                NaN  ...       NaN
# 18654         NaN                NaN  ...       NaN
# 18655         NaN                NaN  ...       NaN
# 18656         NaN                NaN  ...       NaN
# 18657         NaN                NaN  ...       NaN
#
#        sexually_transmitted_infectious_disease  spatially disjoint from  \
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
# ...                                        ...                      ...
# 18653                                      NaN                      NaN
# 18654                                      NaN                      NaN
# 18655                                      NaN                      NaN
# 18656                                      NaN                      NaN
# 18657                                      NaN                      NaN
#
#        subset_property term replaced by  tick-borne_infectious_disease title  \
# 0                  NaN              NaN                            NaN   NaN
# 1                  NaN              NaN                            NaN   NaN
# 2                  NaN              NaN                            NaN   NaN
# 3                  NaN              NaN                            NaN   NaN
# 4                  NaN              NaN                            NaN   NaN
# ...                ...              ...                            ...   ...
# 18653              NaN              NaN                            NaN   NaN
# 18654              NaN              NaN                            NaN   NaN
# 18655              NaN              NaN                            NaN   NaN
# 18656              NaN              NaN                            NaN   NaN
# 18657              NaN              NaN                            NaN   NaN
#
#       TopNodes_DOcancerslim transmitted by zoonotic_infectious_disease
# 0                       NaN            NaN                         NaN
# 1                       NaN            NaN                         NaN
# 2                       NaN            NaN                         NaN
# 3                       NaN            NaN                         NaN
# 4                       NaN            NaN                         NaN
# ...                     ...            ...                         ...
# 18653                   NaN            NaN                         NaN
# 18654                   NaN            NaN                         NaN
# 18655                   NaN            NaN                         NaN
# 18656                   NaN            NaN                         NaN
# 18657                   NaN            NaN                         NaN
#
# [18658 rows x 108 columns]

# %% [markdown]
# ## Download MONDO

# %%
import gdown
import gzip
import shutil

# The URL to download the CSV file
url = "https://data.bioontology.org/ontologies/MONDO/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb&download_format=csv"

# The path where the file will be saved
output = "MONDO.gz"
extracted_file = "MONDO.csv"

# Download the file
gdown.download(url, output, quiet=False)

# Extract the .gz file
with gzip.open(output, 'rb') as f_in:
    with open(extracted_file, 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# Delete the .gz file
os.remove(output)
# Out:
# Downloading...
# From: https://data.bioontology.org/ontologies/MONDO/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb&download_format=csv
# To: G:\Altri computer\Horizon\horizon_workspace\projects\work\semantics\ontology\onto_gene_disease_analysis\data\MONDO.gz
# 100%|██████████| 5.62M/5.62M [00:11<00:00, 473kB/s]

# %% [markdown]
# ## Import MONDO

# %%
# load csv ontology
mondo = pd.read_csv('MONDO.csv', low_memory=False)
onto_label = 'MONDO'
onto = mondo
onto
# Out:
#                                            Class ID  \
# 0      http://purl.obolibrary.org/obo/MONDO_0044647
# 1      http://purl.obolibrary.org/obo/MONDO_1010032
# 2      http://purl.obolibrary.org/obo/MONDO_0007146
# 3      http://purl.obolibrary.org/obo/MONDO_0017964
# 4      http://purl.obolibrary.org/obo/MONDO_0014635
# ...                                             ...
# 34019  http://purl.obolibrary.org/obo/MONDO_0011369
# 34020  http://purl.obolibrary.org/obo/MONDO_0012591
# 34021  http://purl.obolibrary.org/obo/MONDO_0016727
# 34022  http://purl.obolibrary.org/obo/MONDO_0015308
# 34023  http://purl.obolibrary.org/obo/MONDO_0012142
#
#                                          Preferred Label  \
# 0      kyphosis-lateral tongue atrophy-myofibrillar m...
# 1                    Jacobsen syndrome, non-human animal
# 2                          obsolete apnea, central sleep
# 3      obsolete 46,XX disorder of sex development ind...
# 4             microphthalmia, isolated, with coloboma 10
# ...                                                  ...
# 34019        hypercholesterolemia, autosomal dominant, 3
# 34020                     osteogenesis imperfecta type 5
# 34021                       extraventricular neurocytoma
# 34022               laminopathy type Decaudain-Vigouroux
# 34023                                  orofacial cleft 5
#
#                                                 Synonyms  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      46,XX DSD induced by exogenous maternal-derive...
# 4      MCOPCB10|microphthalmia, isolated, with colobo...
# ...                                                  ...
# 34019  Fh3|HCHOLA3|low density lipoprotein cholestero...
# 34020  OI with calcification in interosseous membrane...
# 34021    extraventricular neurocytoma (WHO grade II)|EVN
# 34022  laminopathy with severe metabolic syndrome and...
# 34023  OFC5|cleft lip with or without cleft palate, n...
#
#                                              Definitions  Obsolete  CUI  \
# 0                                                    NaN     False  NaN
# 1      Jacobsen syndrome that occurs in non-human ani...     False  NaN
# 2                                                    NaN      True  NaN
# 3                                                    NaN      True  NaN
# 4      Any microphthalmia, isolated, with coloboma in...     False  NaN
# ...                                                  ...       ...  ...
# 34019  Any familial hypercholesterolemia in which the...     False  NaN
# 34020  Osteogenesis imperfecta type V is a moderate t...     False  NaN
# 34021  Extraventricular neurocytoma (EVN), a variant ...     False  NaN
# 34022  Laminopathy, type Decaudain-Vigouroux is chara...     False  NaN
# 34023  Any orofacial cleft in which the cause of the ...     False  NaN
#
#        Semantic Types                                            Parents  \
# 0                 NaN       http://purl.obolibrary.org/obo/MONDO_0018943
# 1                 NaN  http://purl.obolibrary.org/obo/MONDO_1011360|h...
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN       http://purl.obolibrary.org/obo/MONDO_0000170
# ...               ...                                                ...
# 34019             NaN       http://purl.obolibrary.org/obo/MONDO_0005439
# 34020             NaN  http://purl.obolibrary.org/obo/MONDO_0019019|h...
# 34021             NaN       http://purl.obolibrary.org/obo/MONDO_0016729
# 34022             NaN       http://purl.obolibrary.org/obo/MONDO_0021187
# 34023             NaN  http://purl.obolibrary.org/obo/MONDO_0016044|h...
#
#        A synonym that is historic and discouraged  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 34019                                         NaN
# 34020                                         NaN
# 34021                                         NaN
# 34022                                         NaN
# 34023                                         NaN
#
#        A synonym that is recorded for consistency with another source but is a misspelling  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 34019                                                NaN
# 34020                                                NaN
# 34021                                                NaN
# 34022                                                NaN
# 34023                                                NaN
#
#        ...  realized in response to stimulus  seeAlso  shorthand  \
# 0      ...                               NaN      NaN        NaN
# 1      ...                               NaN      NaN        NaN
# 2      ...                               NaN      NaN        NaN
# 3      ...                               NaN      NaN        NaN
# 4      ...                               NaN      NaN        NaN
# ...    ...                               ...      ...        ...
# 34019  ...                               NaN      NaN        NaN
# 34020  ...                               NaN      NaN        NaN
# 34021  ...                               NaN      NaN        NaN
# 34022  ...                               NaN      NaN        NaN
# 34023  ...                               NaN      NaN        NaN
#
#        should_conform_to subset_property  \
# 0                    NaN             NaN
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
# ...                  ...             ...
# 34019                NaN             NaN
# 34020                NaN             NaN
# 34021                NaN             NaN
# 34022                NaN             NaN
# 34023                NaN             NaN
#
#       Synonym to be removed from public release but maintained in edit version as record of external usage  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 34019                                                NaN
# 34020                                                NaN
# 34021                                                NaN
# 34022                                                NaN
# 34023                                                NaN
#
#       synonym_type_property term replaced by transmitted by  \
# 0                       NaN              NaN            NaN
# 1                       NaN              NaN            NaN
# 2                       NaN    MONDO:0008807            NaN
# 3                       NaN              NaN            NaN
# 4                       NaN              NaN            NaN
# ...                     ...              ...            ...
# 34019                   NaN              NaN            NaN
# 34020                   NaN              NaN            NaN
# 34021                   NaN              NaN            NaN
# 34022                   NaN              NaN            NaN
# 34023                   NaN              NaN            NaN
#
#       UK spelling synonym
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 34019                 NaN
# 34020                 NaN
# 34021                 NaN
# 34022                 NaN
# 34023                 NaN
#
# [34024 rows x 139 columns]

# %%
import tiktoken

def load_file(file='', path=os.getcwd()):
    with open(os.path.join(path, file),'r', encoding='utf-8') as file:
        my_file = file.read()
        file.close()
    return my_file

# Initialize the tokenizer for the specified encoder
tokenizer = tiktoken.encoding_for_model("gpt-4")

# Load the file and count the tokens
tokens = len(tokenizer.encode(str(load_file(file='DOID.csv'))))
tokens
# Out:
# 3587462

# %%
tokens = len(tokenizer.encode(str(load_file(file='MONDO.csv'))))
tokens
# Out:
# 11244106

# %% [markdown]
# ## Extract Ontology class Synonims as list

# %%
onto.Synonyms
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3        46,XX DSD induced by exogenous maternal-derive...
# 4        MCOPCB10|microphthalmia, isolated, with colobo...
#                                ...
# 34019    Fh3|HCHOLA3|low density lipoprotein cholestero...
# 34020    OI with calcification in interosseous membrane...
# 34021      extraventricular neurocytoma (WHO grade II)|EVN
# 34022    laminopathy with severe metabolic syndrome and...
# 34023    OFC5|cleft lip with or without cleft palate, n...
# Name: Synonyms, Length: 34024, dtype: object

# %%
# Function to split the synonyms and return as a list
def split_synonyms(synonyms):
    if synonyms is None:
        return []
    return synonyms.split('|')
    
# Apply the function to create the new column
def df_splitter(df):
    df['Synonyms'] = df['Synonyms'].astype(str)
    df['synonims_list'] = df['Synonyms'].apply(lambda x: split_synonyms(x))
    return df


# Function to add value to lists
def add_value(row):
    row['synonims_list'].append(row['Preferred Label'])
    return row

# Composite Function
def extract_syn_list(onto):
    onto = df_splitter(onto)
    
    # Apply the function to each row
    onto = onto.apply(add_value, axis=1)
    return onto

# %%
onto = extract_syn_list(onto)

# Output the updated DataFrame
onto[['synonims_list','Preferred Label']]
# Out:
#                                            synonims_list  \
# 0      [nan, kyphosis-lateral tongue atrophy-myofibri...
# 1             [nan, Jacobsen syndrome, non-human animal]
# 2                   [nan, obsolete apnea, central sleep]
# 3      [46,XX DSD induced by exogenous maternal-deriv...
# 4      [MCOPCB10, microphthalmia, isolated, with colo...
# ...                                                  ...
# 34019  [Fh3, HCHOLA3, low density lipoprotein cholest...
# 34020  [OI with calcification in interosseous membran...
# 34021  [extraventricular neurocytoma (WHO grade II), ...
# 34022  [laminopathy with severe metabolic syndrome an...
# 34023  [OFC5, cleft lip with or without cleft palate,...
#
#                                          Preferred Label
# 0      kyphosis-lateral tongue atrophy-myofibrillar m...
# 1                    Jacobsen syndrome, non-human animal
# 2                          obsolete apnea, central sleep
# 3      obsolete 46,XX disorder of sex development ind...
# 4             microphthalmia, isolated, with coloboma 10
# ...                                                  ...
# 34019        hypercholesterolemia, autosomal dominant, 3
# 34020                     osteogenesis imperfecta type 5
# 34021                       extraventricular neurocytoma
# 34022               laminopathy type Decaudain-Vigouroux
# 34023                                  orofacial cleft 5
#
# [34024 rows x 2 columns]

# %%
# %%time
doid = extract_syn_list(doid)
doid[['synonims_list','Preferred Label']].head()
# Out:
# CPU times: total: 1.05 s
# Wall time: 1.05 s
#                                        synonims_list  \
# 0        [nan, obsolete infectious canine hepatitis]
# 1                           [nan, spinal nerve root]
# 2  [Arthropathy associated with hypersensitivity ...
# 3  [Hydrops fetalis due to isoimmunization [dup] ...
# 4          [nan, kernicterus due to isoimmunization]
#
#                                      Preferred Label
# 0               obsolete infectious canine hepatitis
# 1                                  spinal nerve root
# 2  obsolete arthropathy due to hypersensitivity r...
# 3                    obsolete immune hydrops fetalis
# 4                 kernicterus due to isoimmunization

# %%
# %%time
mondo = extract_syn_list(mondo)
mondo[['synonims_list','Preferred Label']].head()
# Out:
# CPU times: total: 2.25 s
# Wall time: 2.32 s
#                                        synonims_list  \
# 0  [nan, kyphosis-lateral tongue atrophy-myofibri...
# 1         [nan, Jacobsen syndrome, non-human animal]
# 2               [nan, obsolete apnea, central sleep]
# 3  [46,XX DSD induced by exogenous maternal-deriv...
# 4  [MCOPCB10, microphthalmia, isolated, with colo...
#
#                                      Preferred Label
# 0  kyphosis-lateral tongue atrophy-myofibrillar m...
# 1                Jacobsen syndrome, non-human animal
# 2                      obsolete apnea, central sleep
# 3  obsolete 46,XX disorder of sex development ind...
# 4         microphthalmia, isolated, with coloboma 10

# %% [markdown]
# # Ontology Matcher

# %%
# Dataset column to match
ds.phenotype_description
# Out:
# 0                Endometrial Endometrioid Adenocarcinoma
# 1                                 Hepatobiliary Neoplasm
# 2                                                     ND
# 3      Ovarian Endometrioid Adenocarcinoma with Squam...
# 4                                 Uterine Carcinosarcoma
#                              ...
# 451                                       skin carcinoma
# 452                            Small cell lung carcinoma
# 453                                  soft tissue sarcoma
# 454                         squamous cell lung carcinoma
# 455                                    thyroid carcinoma
# Name: phenotype_description, Length: 456, dtype: object

# %%
# chack data
for index, syn_list in enumerate(onto['synonims_list'][:10]):
    print(index, syn_list)
# Out:
# 0 ['nan', 'obsolete infectious canine hepatitis']
# 1 ['nan', 'spinal nerve root']
# 2 ['Arthropathy associated with hypersensitivity reaction', 'Arthropathy associated with a hypersensitivity reaction (disorder)', 'obsolete arthropathy due to hypersensitivity reaction']
# 3 ['Hydrops fetalis due to isoimmunization [dup] (disorder)', 'Hydrops fetalis due to isoimmunization (disorder)', 'Hydrops fetalis due to isoimmunization', 'Hydrops fetalis - due to isoim', 'obsolete immune hydrops fetalis']
# 4 ['nan', 'kernicterus due to isoimmunization']
# 5 ['muscular dystrophy-dystroglycanopathy limb-girdle GMPPB-related', 'muscular dystrophy-dystroglycanopathy (limb-girdle) type C14', 'muscular dystrophy limb-girdle type 2T', 'MDDGC14', 'LGMD2T', 'autosomal recessive limb-girdle muscular dystrophy type 2T']
# 6 ['muscular dystrophy-dystroglycanopathy (limb-girdle) type C7', 'muscular dystrophy limb-girdle type 2U', 'autosomal recessive limb-girdle muscular dystrophy due to ISPD deficiency', 'MDDGC7', 'LGMD2U', 'autosomal recessive limb-girdle muscular dystrophy type 2U']
# 7 ['muscular dystrophy-dystroglycanopathy (limb-girdle) type C 1', 'muscular dystrophy limb-girdle type 2K', 'limb-girdle muscular dystrophy-intellectual disability syndrome', 'MDDGC1', 'LGMD2K', 'autosomal recessive limb-girdle muscular dystrophy type 2K']
# 8 ['muscular dystrophy-dystroglycanopathy limb-girdle POMT2-related', 'muscular dystrophy-dystroglycanopathy (limb-girdle) type C 2', 'LGMD2N', 'autosomal recessive limb-girdle muscular dystrophy type 2N']
# 9 ['muscular dystrophy, limb-girdle, type 2X', 'LGMD2X', 'autosomal recessive limb-girdle muscular dystrophy type 2X']

# %%
# check data by id
id = 314
doid['synonims_list'].iloc[id], doid['Class ID'].iloc[id]
# Out:
# (['nan', 'microcephaly, growth deficiency, seizures, and brain malformations'],
#  'http://purl.obolibrary.org/obo/DOID_0081051')

# %% [raw]
# # Create a dictionary of data
# data = {'Name': ['John', 'Jane', 'Mike'],
#         'Age': [25, 30, 35],
#         'Salary': [50000, 60000, 70000]}
#
# # Create the dataframe
# df = pd.DataFrame(data)
#
# for index, row in df.iterrows():
#     print('\n',index)
#     print(row)
#     print(type(row))
#     print(row.tolist())
#     print(row.index)

# %%
# check syn list
for syn_list in doid['synonims_list']:
    print(syn_list)
# Out:
# ['nan', 'obsolete infectious canine hepatitis']
# ['nan', 'spinal nerve root']
# ['Arthropathy associated with hypersensitivity reaction', 'Arthropathy associated with a hypersensitivity reaction (disorder)', 'obsolete arthropathy due to hypersensitivity reaction']
# ['Hydrops fetalis due to isoimmunization [dup] (disorder)', 'Hydrops fetalis due to isoimmunization (disorder)', 'Hydrops fetalis due to isoimmunization', 'Hydrops fetalis - due to isoim', 'obsolete immune hydrops fetalis']
# ['nan', 'kernicterus due to isoimmunization']
# ['muscular dystrophy-dystroglycanopathy limb-girdle GMPPB-related', 'muscular dystrophy-dystroglycanopathy (limb-girdle) type C14', 'muscular dystrophy limb-girdle type 2T', 'MDDGC14', 'LGMD2T', 'autosomal recessive limb-girdle muscular dystrophy type 2T']
# ['muscular dystrophy-dystroglycanopathy (limb-girdle) type C7', 'muscular dystrophy limb-girdle type 2U', 'autosomal recessive limb-girdle muscular dystrophy due to ISPD deficiency', 'MDDGC7', 'LGMD2U', 'autosomal recessive limb-girdle muscular dystrophy type 2U']
# ['muscular dystrophy-dystroglycanopathy (limb-girdle) type C 1', 'muscular dystrophy limb-girdle type 2K', 'limb-girdle muscular dystrophy-intellectual disability syndrome', 'MDDGC1', 'LGMD2K', 'autosomal recessive limb-girdle muscular dystrophy type 2K']
# ['muscular dystrophy-dystroglycanopathy limb-girdle POMT2-related', 'muscular dystrophy-dystroglycanopathy (limb-girdle) type C 2', 'LGMD2N', 'autosomal recessive limb-girdle muscular dystrophy type 2N']
# ['muscular dystrophy, limb-girdle, type 2X', 'LGMD2X', 'autosomal recessive limb-girdle muscular dystrophy type 2X']
# ['LCA10', 'Leber congenital amaurosis 10']
# ['muscular dystrophy-dystroglycanopathy limb-girdle POMGNT1-related', 'muscular dystrophy-dystroglycanopathy (limb-girdle) type C3', 'MDDGC3', 'LGMD2O', 'autosomal recessive limb-girdle muscular dystrophy type 2O']
# ['muscular dystrophy-dystroglycanopathy (limb-girdle) type C 4', 'MDDGC4', 'LGMD2M', 'autosomal recessive limb-girdle muscular dystrophy type 2M']
# ['muscular dystrophy-dystroglycanopathy limb-girdle DAG1-related', 'muscular dystrophy-dystroglycanopathy (limb-girdle) type C9', 'MDDGC9', 'LGMD2P', 'autosomal recessive limb-girdle muscular dystrophy type 2P']
# ['muscular dystrophy-dystroglycanopathy limb-girdle FRKP-related', 'muscular dystrophy-dystroglycanopathy (limb-girdle) type C 5', 'muscular dystrophy limb-girdle type 2I', 'MDDGC5', 'Limb-girdle muscular dystrophy due to FKRP deficiency', 'LGMD2I', 'autosomal recessive limb-girdle muscular dystrophy type 2I']
# ['isonicotinylhydrazide allergy', 'INH allergy', 'isoniazide allergy']
# ['carbamazepen allergy', 'Tegretol allergy', 'carbamazepine allergy']
# ['nan', 'shrimp allergy']
# ['xylocaine allergy', 'lignocaine allergy', 'Lidoderm allergy', 'lidocaine allergy']
# ['penicillin G allergy', 'benzyl penicillin allergy', 'benzylpenicillin allergy']
# ['acetylsalicylic acid allergy', 'ASA allergy', 'aspirin allergy']
# ['ABC allergy', 'abacavir allergy']
# ['nan', 'amoxicillin allergy']
# ['rocephin allergy', 'ceftriaxone allergy']
# ['Inborn error of pyruvate metabolism (disorder)', 'obsolete inborn errors pyruvate metabolism']
# ['nan', 'imidazolidines']
# ['nan', 'bony pelvis']
# ['disease due to Paramyxovirus (disorder)', 'obsolete Respirovirus infectious disease']
# ['Labour complications', 'obsolete labor complications']
# ['nan', 'obsolete polyglandular dysfunction']
# ['nan', 'obsolete papilledema associated with increased intracranial pressure']
# ['secondary malignant neoplasm of thyroid gland', 'metastatic tumor to the Thyroid', 'obsolete metastatic malignant neoplasm to the thyroid']
# ["Wermer's syndrome", 'Wermer syndrome', 'MEN type I', 'multiple endocrine neoplasia type 1']
# ['nan', 'thyroid lymphoma']
# ['mucosal neuroma syndrome', 'Wagenmann-Froboese syndrome', 'Multiple endocrine neoplasia, type 3', 'MEN2B', 'MEN type IIB', 'multiple endocrine neoplasia type 2B']
# ['nan', 'obsolete polyglandular activity in multiple endocrine adenomatosis']
# ['nan', 'epithelial cell of exocrine pancreas']
# ['duct carcinoma', 'breast ductal carcinoma']
# ['nan', 'susceptibility to nasopharyngeal carcinoma 3']
# ['retinal arterial branch occlusion', 'Arterial retinal branch occlusion', 'branch retinal artery occlusion']
# ['Vertebral artery syndrome', 'vertebral artery insufficiency']
# ['nan', 'central retinal artery occlusion']
# ['Idiopathic livedo reticularis with systemic involvement', 'Sneddon syndrome']
# ['progressive intracranial arterial occlusion', 'Moyamoya disease']
# ['nan', 'intracranial arteriosclerosis']
# ['uterine corpus endometrial stromal tumor', 'uterine corpus endometrial stromal sarcoma']
# ['myopia-night blindness', 'hemeralopia-myopia', 'congenital stationary night blindness with myopia', 'congenital stationary night blindness 1A X-linked', 'complete CSNB X-linked', 'NBMI', 'CSNB1A', 'congenital stationary night blindness 1A']
# ['pituitary anomalies with holoprosencephaly-like features', 'holoprosencephaly with microphthalmia and first branchial arch anomalies', 'HPE9', 'holoprosencephaly 9']
# ['HPE2', 'holoprosencephaly 2']
# ['HPE3', 'HLP3', 'holoprosencephaly 3']
# ['congenital stationary night blindness 2A X-linked', 'congenital stationary night blindness 2A']
# ['HPE6', 'holoprosencephaly 6']
# ['HPE7', 'holoprosencephaly 7']
# ['HPE8', 'holoprosencephaly 8']
# ['HPE11', 'holoprosencephaly 11']
# ['HPE5', 'holoprosencephaly 5']
# ['nan', 'penicillin']
# ['polyp, uterus', 'polyp of the Uterus', 'polyp of Endometrium', 'endometrial/uterine polyp', 'polyp of corpus uteri']
# ['nan', 'skeletal muscle organ, vertebrate']
# ['gastric G-cell gastrin producing tumor', 'gastric gastrinoma']
# ['nan', 'Abnormal fundus morphology']
# ['Prodromal angle closure glaucoma', 'Intermittent angle-closure glaucoma', 'Angle-closure glaucoma, subacute', 'interval angle-closure glaucoma']
# ['nan', 'hyperparathyroidism']
# ['Normal tension glaucoma', 'low tension glaucoma']
# ['secondary parkinsonism', 'disorder presenting primarily with parkinsonism', 'Symptomatic parkinsonism', 'secondary Parkinson disease']
# ['nan', 'testicular spermatocytic seminoma']
# ['nan', 'susceptibility to chordoma']
# ['nan', 'astrocytoma, IDH-mutant, grade 3']
# ['desmoplastic infantile ganglioglioma and desmoplastic infantile astrocytoma', 'desmoplastic infantile ganglioglioma', 'Desmoplastic Infantile Astrocytoma', 'desmoplastic infantile ganglioglioma / desmoplastic infantile astrocytoma']
# ['Papillary tumour of the pineal region', 'papillary tumor of the pineal region']
# ['Capicua transcriptional repressor (CIC)-rearranged sarcoma', 'CIC-rearranged sarcoma']
# ['Posterior fossa group A (PFA) ependymoma', 'Posterior Fossa Ependymoma, Group A (PFA)', 'posterior fossa group A ependymoma']
# ['nan', 'supratentorial ependymoma, ZFTA fusion–positive']
# ['nan', 'supratentorial ependymoma, YAP1 fusion–positive']
# ['nan', 'astrocytoma, IDH-mutant, grade 2']
# ['Posterior fossa group B (PFB) ependymoma', 'Posterior Fossa Ependymoma, Group B (PFB)', 'posterior fossa group B ependymoma']
# ['recurrent gastric cancer', 'recurrent carcinoma of the stomach', 'obsolete recurrent stomach cancer']
# ['retina circulation disorder', 'retinal vascular disease']
# ['nan', 'Ribozyviria']
# ['uricacidemia', 'Blood urate raized', 'hyperuricemia']
# ['nan', 'co-trimoxazole']
# ['epithelioid and spindle cell nevus (disorder)', 'Spitz (spindle cell) nevus', 'Pigmented spindle cell naevus of Reed', 'obsolete epithelioid and spindle cell nevus']
# ['schizophrenia-1', 'schizophrenia']
# ['nan', 'conserved_intergenic_variant']
# ['nan', '5_prime_UTR_truncation']
# ['nan', 'pyrrolysine_loss']
# ['nan', '5_prime_UTR_elongation']
# ['nan', '3_prime_UTR_elongation']
# ['nan', 'start_lost']
# ['nan', '3_prime_UTR_truncation']
# ['nan', 'intragenic_variant']
# ['nan', 'conserved_intron_variant']
# ['nan', 'start_retained_variant']
# ['nan', 'malignant ovarian surface epithelial-stromal neoplasm']
# ['cyclic agranulocytosis', 'Neutropenia, periodic', 'Cyclical neutropenia', 'Cyclic neutropenia', 'cyclic hematopoiesis']
# ['stage 0 Colonic carcinoma', 'carcinoma in situ of colon', 'colon carcinoma in situ']
# ['nan', 'obsolete cutaneous listeriosis']
# ['nan', 'obsolete Listeria meningoencephalitis']
# ['nan', 'obsolete Yersinia pestis infectious disease']
# ['nan', 'obsolete abortive plague']
# ['nan', 'erysipeloid']
# ['nan', 'obsolete Listeria septicaemia']
# ['nan', 'obsolete pestis minor']
# ['nan', 'fallopian tube leiomyoma']
# ['nan', 'Abnormal knee morphology']
# ['Retinal Dystrophy', 'fundus dystrophy']
# ['nan', 'cobalt atom']
# ['nan', 'obsolete extracutaneous melanoma']
# ['bacterial diarrhea', 'Gastroenteritis - bact.', 'Bacterial gastroenteritis (disorder)', 'obsolete bacterial gastroenteritis']
# ['Syphilis of kidney (disorder)', 'Syphilis of kidney', 'obsolete renal syphilis']
# ['Syphilis of lung (disorder)', 'obsolete pulmonary syphilis']
# ['Salmonellosis (& [gastroenteritis] or [food poisoning])', 'Salmonellosis', 'Salmonella gastroenteritis [Ambiguous]', 'Salmonella gastroenteritis (disorder)', 'Salmonella gastroenteritis', 'Salmonella food poisoning (disorder)', 'Salmonella food poisoning', 'Enteric paratyphosis', 'obsolete Salmonella gastroenteritis']
# ['nan', 'obsolete primary Rickettsiaceae infectious disease']
# ['respiratory condition of fetus OR newborn (disorder)', 'Unspecified respiratory condition of fetus and newborn', 'Perinatal respiratory problems NOS (disorder)', 'Perinatal respiratory problems NOS', 'obsolete perinatal respiratory disorder']
# ['nan', 'susceptibility to familial breast-ovarian cancer 3']
# ['Streptococcus pneumoniae septicemia', 'Septicemia due to streptococcus pneumoniae (disorder)', 'Septicaemia due to streptococcus pneumoniae', 'Pneumococcal septicemia [Streptococcus pneumoniae septicemia]', 'Pneumococcal septicemia (disorder)', 'obsolete pneumococcal septicemia']
# ['tumor of ethmoidal sinus', 'neoplasm of ethmoidal sinus', 'ethmoidal sinus benign neoplasm']
# ['nan', 'obsolete paranoid state']
# ['nan', 'polyneuropathy in collagen vascular disease']
# ['Pseudoexfoliation syndrome', 'Pseudoexfoliation glaucoma', 'exfoliation syndrome']
# ['Streptococcal septicemia, unspecified (disorder)', 'Streptococcal septicemia (disorder)', 'obsolete streptococcal septicemia']
# ['Constitutional aplastic anaemia', 'congenital hypoplastic anaemia', 'congenital aplastic anemia', 'congenital aplastic anaemia', 'congenital hypoplastic anemia']
# ['nan', 'obsolete subcutaneous ascomycota mycosis']
# ['nan', 'obsolete Neoscytalidium dimidiatum infectious disease']
# ['nan', 'Trichomonas tenax trichomoniasis']
# ['nan', 'basidiobolomycosis']
# ['nan', 'obsolete Scopulariopsis infectious disease']
# ['nan', 'obsolete cutaneous basidiomycota mycosis']
# ['nan', 'obsolete onychomycosis']
# ['nan', 'obsolete cutaneous ascomycota mycosis']
# ['nan', 'obsolete subcutaneous fungi incertae sedis mycosis']
# ['nan', 'conidiobolomycosis']
# ['OCD', 'osteochondritis dissecans']
# ['chronic depressive personality disorder', 'chronic depression (disorder)', 'obsolete chronic depressive disorder']
# ["cork-handlers' lung", "cork-handlers' disease or lung", 'Suberosis', "cork-handlers' disease"]
# ['Rheumatoid lung', 'rheumatoid arthritis interstitial lung disease']
# ['Cyclothymic personality', 'Cyclothymia', 'Cycloid personality', 'Affective personality disorder', 'cyclothymic disorder']
# ['nan', 'obsolete arthropathy associated with hematological disorder']
# ['Inflammatory disorder of joint', 'arthritis']
# ['hypersensitivity pneumonitis', 'alveolitis', 'extrinsic allergic alveolitis']
# ['recurrent Neuroepithelioma of bone', 'obsolete bone recurrent PNET']
# ['nan', 'mechanical transmission']
# ['nan', 'theca cell']
# ['nan', 'granulosa cell']
# ['nan', 'follicular epithelial cell']
# ['nan', 'beta thalassemia']
# ['Histoplasmosis with endocarditis (disorder)', 'Histoplasma capsulatum with endocarditis (disorder)', 'Histoplasma capsulatum endocarditis', 'obsolete histoplasmosis endocarditis']
# ['Histoplasmosis with meningitis', 'histoplasmosis meningitis']
# ['deficiency, labile', 'Proaccelerin deficiency', 'Labile factor deficiency', 'Hereditary hypoproaccelerinaemia', 'factor V deficiency']
# ['german measles', 'rubella']
# ['nan', 'psoriasis']
# ['Non-metastatic malignant hemangiopericytoma', 'obsolete malignant hemangiopericytoma nonmetastatic']
# ['nan', 'obsolete dissecting aortic aneurysm']
# ['nan', 'sandfly fever Sicilian virus']
# ['influenza with non-respiratory manifestation', 'flu', 'Influenza with other manifestations', 'influenza']
# ['nan', 'Borreliella burgdorferi']
# ['nan', 'Bacillus anthracis']
# ['adenocarcinoma of the uterine Cervix', 'adenocarcinoma of cervix', 'adenocarcinoma cervix uteri', 'cervical adenocarcinoma']
# ['nan', 'digestive tract diverticulum']
# ['nan', 'sac']
# ['nan', 'body of uterus']
# ['Purulent conjunctivitis', 'bacterial conjunctivitis']
# ['Occult large cell carcinoma of the lung', 'lung occult large cell carcinoma']
# ['type I diabetes mellitus', 'insulin-dependent diabetes mellitus', 'IDDM', 'type 1 diabetes mellitus']
# ['nan', 'papillary cystadenocarcinoma']
# ['nan', 'tic disorder']
# ['nan', 'Abnormal fetal morphology']
# ['nan', 'Fetal anomaly']
# ['Quie syndrome', 'Congenital dysphagocytosis', 'CGD', 'Bridges-Good syndrome', 'chronic granulomatous disease']
# ['Isolated cytochrome C oxidase deficiency', 'COX deficiency, benign infantile mitochondrial myopathy']
# ['lacrimoauriculodentodigital syndrome', 'Lacrimo-auriculo-dento-digital (LADD) syndrome', 'LADD syndrome']
# ['Lacrimo-auriculo-dento-digital syndrome 2', 'lacrimoauriculodentodigital syndrome 2']
# ['Lacrimo-auriculo-dento-digital syndrome 3', 'lacrimoauriculodentodigital syndrome 3']
# ['disabling pansclerotic morphea of childhood', 'disabling pansclerotic morphea']
# ['nan', 'nemaline myopathy 5C']
# ['nan', 'obsolete sorbitol dehydrogenase deficiency with peripheral neuropathy']
# ['nan', 'amyotrophic lateral sclerosis type 24']
# ['nan', 'amyotrophic lateral sclerosis type 25']
# ['nan', 'nemaline myopathy 5B']
# ['renal diabetes', 'renal glycosuria']
# ['nan', 'head']
# ['nan', 'acute conjunctivitis']
# ['nan', 'pulp degeneration']
# ['nan', 'serous glue ear']
# ['Septicemia due to hemophilus influenzae [H. influenzae]', 'Septicemia due to H. influenzae', 'Hemophilus influenzae septicemia (disorder)', 'obsolete Haemophilus influenzae septicemia']
# ['nan', 'obsolete chronic otitis media with effusion']
# ['Petriellidosis', 'allescheriosis']
# ['Nonsuppurative otitis media', 'non-suppurative otitis media']
# ['erythermalgia', 'erythromelalgia']
# ['Arthus type urticaria', 'Arthus phenomenon', 'arthus reaction']
# ['nan', 'obsolete obstructed labor']
# ['nan', 'urethra']
# ['nan', 'large intestine']
# ['nan', 'vessel']
# ['nan', 'duct']
# ['nan', 'ureter']
# ['nan', 'obsolete regressing non-cutaneous melanoma']
# ['nan', 'visceral striated muscle tissue']
# ['nan', 'visceral muscle tissue']
# ['punctate keratosis palmoplantaris', 'punctate palmoplantar hyperkeratosis', 'punctate palmoplantar keratoderma']
# ["autosomal recessive juvenile Parkinson's disease 2", 'autosomal recessive juvenile Parkinson disease 2', "Parkinson's disease 2"]
# ['punctate palmoplantar keratoderma type 3', 'punctate palmoplantar hyperkeratosis type 3', 'acrokeratoelastoidosis of Costa', 'punctate palmoplantar keratoderma type III']
# ['MFDA', 'mandibulofacial dysostosis with alopecia']
# ['lymphedem-lymphangiectasia-intellectual disability syndrome', 'Hennekam lymphangiectasia-lymphedema syndrome', 'Hennekam syndrome']
# ['nan', 'hereditary papulotranslucent acrokeratoderma']
# ["autosomal dominant Parkinson's disease 1", 'autosomal dominant Parkinson disease 1', "Parkinson's disease 1"]
# ['nephrosis-neuronal dysmigration syndrome', 'nephrosis-microcephaly syndrome', 'microcephaly, hiatal hernia and nephrotic syndrome', 'autosomal recessive spinocerebellar ataxia 5', 'SCAR5', 'Galloway syndrome', 'Galloway-Mowat syndrome 1']
# ['nan', 'glycerol kinase deficiency']
# ['early-onset Parkinson disease 6', "autosomal recessive early-onset Parkinson's disease 6", 'autosomal recessive early-onset Parkinson disease 6', 'PARK6', "Parkinson's disease 6"]
# ['nan', 'organonitrogen compound']
# ['nan', 'molecule']
# ['nan', 'Ascaridoidea']
# ['mucoviscidosis', 'CF', 'cystic fibrosis']
# ['nan', 'congenital myopathy 9A']
# ['nan', 'congenital myopathy 15']
# ['congenital myopathy-5 with cardiomyopathy', 'Salih myopathy', 'congenital myopathy 5']
# ['nan', 'congenital myopathy 8']
# ['nan', 'congenital myopathy 9B']
# ['nan', 'congenital myopathy 14']
# ['nan', 'congenital myopathy 10B']
# ['nan', 'congenital myopathy 2C']
# ['nan', 'congenital myopathy 16']
# ['nan', 'congenital myopathy 17']
# ['nan', 'serous membrane']
# ['nan', 'ganglion']
# ['nan', 'Abnormality of the integument']
# ['nodular lymphoma of lymph nodes of head, face, and neck (disorder)', 'nodular lymphoma of lymph nodes of head, face and neck (disorder)', 'nodular lymphoma involving lymph nodes of head, face and neck', 'obsolete nodular lymphoma involving lymph nodes of head, face, and neck']
# ['nan', 'obsolete malignant neoplasm of thymus, heart and mediastinum']
# ['autoimmune nervous system disorder', 'autoimmune disease of the nervous system']
# ['nan', 'myasthenia gravis']
# ['nan', 'neuromuscular junction disease']
# ['nan', 'myofascial pain syndrome']
# ['nan', 'obsolete anterior mediastinum cancer']
# ['nan', 'posterior mediastinum cancer']
# ['nan', 'obsolete Intraventricular hemorrhage from any perinatal cause']
# ['nan', 'nutritional optic neuropathy']
# ['trifocal neuralgia', 'Trifacial neuralgia', 'trigeminal neuralgia']
# ['nan', 'obsolete Galactorrhea associated with childbirth']
# ['Unspecified rat-bite fever', 'Rat-bite fever, unspecified (disorder)', 'Rat-bite fever NOS (disorder)', 'Rat-bite fever', 'Rat bite fever (disorder)', 'obsolete rat-bite fever']
# ['Spirillosis', 'Spirillary fever', 'sodoku disease']
# ['vitamin A deficiency with corneal xerosis (disorder)', 'obsolete vitamin A deficiency with corneal xerosis']
# ['nan', 'ovarian surface epithelial cell']
# ['Persistent tuberculum impar', 'median rhomboid glossitis']
# ['adhesions,tongue-congenital', 'Congenital adhesions of tongue (disorder)', 'Congenital adhesions of tongue', 'obsolete congenital adhesion of tongue']
# ['hyperlipidemia, group A (disorder)', 'Pure hypercholesterolemia NOS (disorder)', 'Pure hypercholesterolemia (disorder)', 'Pure hypercholesterolemia', 'Pure hypercholesterolaemia', 'LDL hyperlipoproteinemia', 'obsolete group A hyperlipidemia']
# ['toxic shock', 'TSS', 'toxic shock syndrome']
# ['multiple symmetrical lipomatosis', 'cervical Symmetrical Lipomatosis', "Madelung's neck", "Launois-Bensaude's lipomatosis", 'LIPOMATOSIS, FAMILIAL BENIGN CERVICAL', 'LIPODYSTROPHY, CEPHALOTHORACIC', 'multiple symmetric lipomatosis']
# ['malignant anal tumor', 'anal cancer', 'anus cancer']
# ['mixed hyperglyceridemia', 'hyperchylomicronemia', 'hypercholesterinaemic xanthomatosis', 'familial hyperlipoproteinemia type I', 'familial LPL deficiency', 'Fredrickson type I lipaemia', 'Fredrickson type I hyperlipoproteinemia', 'familial lipoprotein lipase deficiency']
# ['nan', 'autosomal dominant craniometaphyseal dysplasia']
# ['nan', 'salivary gland mucinous adenocarcinoma']
# ['nan', 'cranioectodermal dysplasia 1']
# ['nan', 'autosomal recessive craniometaphyseal dysplasia']
# ['nan', 'cranioectodermal dysplasia 3']
# ['nan', 'chronic asthma']
# ['nan', 'mammary analogue secretory carcinoma']
# ['nan', 'cranioectodermal dysplasia 2']
# ['nan', 'autosomal dominant craniodiaphyseal dysplasia']
# ['nan', 'cranioectodermal dysplasia 4']
# ['familial hypertriglyceridemia', 'VLDL hyperlipoproteinemia', 'Fredrickson type IV lipidaemia', 'Fredrickson type IV hyperlipoproteinemia', 'Fredrickson type IV Lipidemia', 'Endogenous hyperlipidaemia', 'hyperlipoproteinemia type IV']
# ['limb girdle muscular dystrophy', 'Leyden-Mbius muscular dystrophy', "Erb's muscular dystrophy", 'limb-girdle muscular dystrophy']
# ['Muscular dystrophy, Landouzy-Dejerine', 'Landouzy-Dejerine muscular dystrophy', 'Landouzy Dejerine muscular dystrophy', 'facioscapulohumeral muscular dystrophy']
# ['De Lange syndrome', 'Brachmann de Lange syndrome', 'Cornelia de Lange syndrome']
# ['myotonic dystrophy of Steinert', 'congenital myotonic dystrophy', 'Steinert disease', 'Dystrophia myotonica', 'myotonic dystrophy type 1']
# ['Muscular dystrophy, Duchenne', 'Duchenne muscular dystrophy']
# ['distal muscular dystrophy', 'distal myopathy']
# ['neuroborreliosis', 'lyme neuroborreliosis', 'Neurological Lyme disease', 'Lyme borreliosis', "Bannworth's syndrome", 'Bannwarth syndrome', 'Lyme disease']
# ['EDMD', 'Emery-Dreifuss muscular dystrophy']
# ['phosphofructokinase myopathy', 'glycogen storage disease type VII', 'Muscle phosphofructokinase deficiency', 'Glycogen storage disease, type VII', 'Glycogen storage disease 7', 'glycogen storage disease VII']
# ['pediatric tumor of Brainstem', 'childhood brain stem neoplasm']
# ['nan', 'Rhinocladiella mackenziei']
# ['Liposarcoma of the stomach', 'gastric liposarcoma']
# ['nan', 'proliferative glomerulonephritis']
# ['penis Paget disease', "Paget's disease of penis", "penis Paget's disease"]
# ['secondary malignant neoplasm of spinal cord (disorder)', 'metastatic tumor to the Spinal Cord', 'obsolete spinal cord secondary cancer']
# ['adenocarcinoma of nasal cavity', 'adenocarcinoma of the nasal cavity', 'nasal cavity adenocarcinoma']
# ['nan', 'obsolete intracranial melanoma']
# ['nan', 'Involuntary vocalization']
# ['nan', 'Abnormal language feature']
# ['nan', 'radioulnar synostosis']
# ['squamous cell carcinoma, sarcomatoid', 'spindle cell squamous cell carcinoma', 'spindle cell squamous carcinoma of skin', 'spindle cell (sarcomatoid) squamous cell skin carcinoma', 'spindle cell (sarcomatoid) squamous cell carcinoma', 'sarcomatoid squamous cell skin carcinoma']
# ['SC phocomelia syndrome', 'Roberts-Sc Phocomelia Syndrome', 'RBS', 'LONG BONE DEFICIENCIES ASSOCIATED WITH CLEFT LIP-PALATE', 'Roberts syndrome']
# ['nan', 'Actinobacillus ureae']
# ['nan', 'Abnormal circulating nitrogen compound concentration']
# ['nan', 'Abnormality of acid-base homeostasis']
# ['nan', 'Senile atrophy of choroid']
# ['nan', 'bilateral renal aplasia']
# ['nan', 'adenoid cystic carcinoma']
# ['Peters-plus syndrome', 'Peters anomaly-short limb dwarfism syndrome', 'Krause-Kivlin syndrome', 'Peters plus syndrome']
# ['Congenital anomalies of the kidney and urinary tract 2', 'CAKUT2']
# ['Congenital anomalies of the kidney and urinary tract 1', 'CAKUT1']
# ['SIFD', 'sideroblastic anemia with B-cell immunodeficiency, periodic fevers, and developmental delay']
# ['Renal or urinary tract malformation', 'Congenital anomalies of the kidney and urinary tract', 'CAKUT']
# ['nonalcoholic fatty liver disease', 'non-alcoholic fatty liver disease', 'metabolic-associated fatty liver disease', 'metabolic dysfunction-related steatotic liver disease', 'metabolic dysfunction-associated fatty liver disease', 'NAFLD', 'MASLD', 'MAFLD', 'metabolic dysfunction-associated steatotic liver disease']
# ['nan', 'renal hypoplasia']
# ['nan', 'Merbecovirus']
# ['Congenital Epulides', 'congenital epulis']
# ['nan', 'large cell acanthoma']
# ['nan', 'Fonsecaea compacta']
# ['peripheral neuroblastoma', 'obsolete peripheral neuroblastoma']
# ['Blastoma of lung', 'pulmonary blastoma']
# ['nan', 'sebaceous breast carcinoma']
# ['MC4DN10', 'mitochondrial complex IV deficiency nuclear type 10']
# ['MC4DN1', 'mitochondrial complex IV deficiency nuclear type 1']
# ['MC4DN7', 'mitochondrial complex IV deficiency nuclear type 7']
# ['MC4DN12', 'mitochondrial complex IV deficiency nuclear type 12']
# ['PKDYS2', 'Brain dopamine-serotonin vesicular transport disease', 'infantile parkinsonism-dystonia 2']
# ['MC4DN8', 'mitochondrial complex IV deficiency nuclear type 8']
# ['MC4DN3', 'mitochondrial complex IV deficiency nuclear type 3']
# ['MC4DN11', 'mitochondrial complex IV deficiency nuclear type 11']
# ['MC4DN4', 'mitochondrial complex IV deficiency nuclear type 4']
# ['MC4DN14', 'mitochondrial complex IV deficiency nuclear type 14']
# ['childhood choroid plexus neoplasm', 'childhood choroid plexus cancer']
# ['cutaneous gamma/delta T-cell lymphoma', 'Primary Cutaneous Gamma-Delta T Cell Lymphomas', 'primary cutaneous gamma-delta T-cell lymphoma']
# ['nan', 'microcephaly, growth deficiency, seizures, and brain malformations']
# ['nan', 'neurobehavioral disorder with prenatal alcohol exposure']
# ['X-linked neurohypophyseal diabetes insipidus', 'X-linked central diabetes insipidus']
# ['nan', 'central diabetes insipidus']
# ['transient diabetes insipidus of pregnancy', 'gestational diabetes insipidus']
# ['nan', 'dipsogenic diabetes insipidus']
# ['nan', 'ciliopathy']
# ['microcephaly, lymphedema, chorioretinal dysplasia syndrome', 'microcephaly lymphedema chorioretinal dysplasia', 'lymphedema, microcephaly and chorioretinopathy syndrome', 'lymphedema and retinal folds with ficrocephaly and microphthalmos', 'chorioretinal dysplasia-microcephaly-mental retardation syndrome', 'microcephaly with or without chorioretinopathy, lymphedema, or mental retardation']
# ['nan', 'acrorenal syndrome']
# ['congenital myopathy 13', 'Bailey-Bloch congenital myopathy', 'Native American myopathy']
# ['hypoparathyroidism with short stature, mental retardation and seizures', 'Sanjad-Sakati syndrome', 'HRD syndrome', 'hypoparathyroidism-retardation-dysmorphism syndrome']
# ['otocephaly', 'holoprosencephaly-agnathia', 'dysgnathia complex agnathia-holoprosencephaly', 'agnathia-holoprosencephaly-situs inversus syndrome', 'agnathia-otocephaly complex']
# ['steroid-induced osteoporosis', 'glucocorticoid-induced osteoporosis']
# ['nan', 'bacillary angiomatosis']
# ['nan', 'acromelic frontonasal dysostosis']
# ['primary diffuse atrophy', 'Herxheimer disease', 'acrodermatitis chronica atrophicans']
# ['nan', 'Leishmaniinae']
# ['nan', 'Amblyomma cajennense']
# ['nan', 'neck pain']
# ['nan', 'swelling in chest']
# ['nan', 'sinus tachycardia']
# ['nan', 'paroxysmal tachycardia']
# ['VT', 'V-tach', 'ventricular tachycardia']
# ['nan', 'sore eyes']
# ['nan', 'mass in chest']
# ['nan', 'chronic enteritis']
# ['nan', 'sinus bradycardia']
# ['nan', 'junctional tachycardia']
# ['nan', 'ovarian clear cell cystadenocarcinoma']
# ['precursor T-lymphoblastic lymphoma/leukemia', 'acute T cell leukemia', 'T-cell lymphoblastic leukemia/lymphoma', 'T-cell leukemia', 'T-cell acute lymphocytic leukaemia', 'T Acute Lymphoblastic Leukemia', 'Precursor T Lymphoblastic Leukemia', 'T-cell acute lymphoblastic leukemia']
# ['cervical Muellerian papilloma', 'cervical Mullerian papilloma']
# ['cardiomyopathy familial hypertrophic 2', 'CMH2', 'hypertrophic cardiomyopathy 2']
# ['muscular dystrophy limb-girdle type 1G', 'autosomal dominant limb-girdle muscular dystrophy type 1G', 'LGMD1G', 'autosomal dominant limb-girdle muscular dystrophy type 3']
# ['muscular dystrophy limb-girdle type 1E', 'muscular dystrophy limb-girdle type 1D', 'autosomal dominant limb-girdle muscular dystrophy type 1E', 'LGMD1D', 'autosomal dominant limb-girdle muscular dystrophy type 1']
# ['cardiomyopathy familial hypertrophic 3', 'CMH3', 'hypertrophic cardiomyopathy 3']
# ['nan', 'obsolete autosomal dominant limb-girdle muscular dystrophy type 1A']
# ['muscular dystrophy limb-girdle type 1H', 'LGMD1H', 'autosomal dominant limb-girdle muscular dystrophy type 1H']
# ['muscular dystrophy limb-girdle type 1F', 'autosomal dominant limb-girdle muscular dystrophy type 1F', 'LGMD1F', 'autosomal dominant limb-girdle muscular dystrophy type 2']
# ['nan', 'obsolete autosomal dominant limb-girdle muscular dystrophy type 1C']
# ['hypertrophic cardiomyopathy 19', 'cardiomyopathy, familial hypertrophic 1', 'CMH1', 'hypertrophic cardiomyopathy 1']
# ['nan', 'obsolete autosomal dominant limb-girdle muscular dystrophy type 1B']
# ['nan', 'Amniota']
# ['nan', 'oxo carboxylic acid']
# ['nan', 'cell']
# ['nan', 'curator inference from dictionary']
# ['nan', 'Trichophyton equinum']
# ['nan', 'hyperglycemia']
# ['nan', 'obsolete primary Escherichia coli infectious disease']
# ['NAME Syndrome', 'LAMB Syndrome', 'Carney complex variant', 'Carney Syndrome', 'Carney Complex, Type 2', 'Carney Complex, Type 1', 'Carney complex']
# ['Klebsiella infection', 'obsolete commensal Klebsiella infectious disease']
# ['nan', 'monilethrix']
# ['nan', 'Netherton syndrome']
# ['nan', 'Alstrom syndrome']
# ['MGA type II', 'MGA Type 2', '3-methylglutaconicaciduria type II', '3-methylglutaconicaciduria type 2', 'Barth syndrome']
# ['Leprechaunism', 'Donohue syndrome']
# ['congenital mesodermal dystrophy', 'Spherophakia Brachymorphia Syndrome', 'Mesodermal Dysmorphodystrophy, Congenital', 'Marchesani-Weill Syndrome', 'GEMSS syndrome', 'Weill-Marchesani syndrome']
# ['Pseudoaldosteronism', "Liddle's syndrome", 'Liddle syndrome']
# ['nan', 'cervical adenomyoma']
# ['nan', 'Anaplasma']
# ["stromal predominant kidney Wilms' tumour", 'Stromal Predominant renal Wilms tumour', 'Stromal Predominant renal Wilms tumor', "stromal predominant kidney Wilms' tumor"]
# ['nan', 'thyroiditis']
# ['nan', 'hypertrophic elongation of cervix']
# ['sarcoma of the vagina', 'vagina sarcoma']
# ['nan', 'obsolete localized lymphoma']
# ['psoriatic arthropathy', 'arthropathic psoriasis', 'arthritis psoriatica', 'psoriatic arthritis']
# ['Cryptococcal Pneumonia', 'obsolete pulmonary cryptococcosis']
# ['premature retinopathy', 'Retrolental fibroplasia', 'retinopathy of prematurity']
# ['nan', 'transient global amnesia']
# ['Cutaneous blastomycosis', 'infection by Loboa loboi', 'Cutaneous lobomycosis', 'lobomycosis']
# ['nan', 'obsolete AIDS-related cryptococcosis']
# ['Sickle-cell trait', 'Sickle cell trait (disorder)', 'Hb-S trait', 'Haemoglobin S trait', 'obsolete sickle cell trait']
# ['nan', 'obsolete residual schizophrenia chronic state with acute exacerbation']
# ['Lipoma of the Corpus Callosum', 'corpus callosum lipoma']
# ['nan', 'phenyl acetates']
# ['nan', 'Cowper gland carcinoma']
# ['nan', 'obsolete Filoviridae infectious disease']
# ['nan', 'appendicular ossicle']
# ['nan', 'salicylates']
# ['hereditary sensory and autonomic neuropathy type V', 'HSAN5', 'hereditary sensory and autonomic neuropathy type 5']
# ['hereditary sensory and autonomic neuropathy type VII', 'HSAN7', 'hereditary sensory and autonomic neuropathy type 7']
# ['hereditary sensory neuropathy type IB', 'HSAN with cough and gastroesophageal reflux', 'hereditary sensory neuropathy type 1B']
# ['cutis laxa-corneal clouding-intellectual disability syndrome', 'De Barsy syndrome', 'autosomal recessive cutis laxa type III']
# ['autosomal recessive cutis laxa type 1', 'autosomal recessive cutis laxa type I']
# ['insensitivity to pain, congenital, with anhidrosis', 'hereditary sensory neuropathy type IV', 'hereditary sensory neuropathy type 4']
# ['ARCL2, classic type', 'ARCL2, Debre type', 'autosomal recessive cutis laxa type II classic type']
# ['nan', 'autosomal recessive cutis laxa type IIC']
# ['ADCL', 'autosomal dominant cutis laxa']
# ['hereditary sensory neuropathy type IIC', 'HSN2C', 'hereditary sensory neuropathy type 2C']
# ['nan', 'male breast']
# ['nan', 'obsolete ovarian dermoid cyst with secondary tumor']
# ['acute bovine pulmonary emphysema AND edema (disorder)', 'Fog fever', 'Atypical interstitial pneumonia of cattle (disorder)', 'obsolete bovine atypical interstitial pneumonia']
# ['Reticulosarcoma of intra-abdominal lymph nodes (disorder)', 'Reticulosarcoma of intra-abdominal lymph nodes', 'obsolete reticulosarcoma involving intra-abdominal lymph nodes']
# ['ventricular escape rhythm', 'idioventricular rhythm', 'ventricular bradycardia']
# ['v-fib', 'ventricular fibrillation']
# ['nan', 'cold clammy skin']
# ['nan', 'sensation perception']
# ['anaphylaxis', 'anaphylactic shock']
# ['nan', 'hypotensive']
# ['proptosis', 'exophthalmus', 'exophthalmia', 'exophthalmos']
# ['nan', 'cardiac fibrillation']
# ['nan', 'musculoskeletal system symptom']
# ['nan', 'relapsing fever']
# ['nan', 'sequence']
# ['nan', 'angiokeratoma of mibelli']
# ['testicular Intraepithelial Neoplasia', 'ITGCNU', 'obsolete testicular intratubular germ cell neoplasia of the unclassified type']
# ['nan', 'obsolete prolonged labor']
# ['nan', 'Nannizzia gypsea']
# ['nan', 'vulvar syringoma']
# ['mediastinal endodermal sinus neoplasm', 'Yolk Sac tumor of mediastinum', 'obsolete mediastinal endodermal sinus tumor']
# ['nan', 'Erysipelotrichia']
# ['nan', 'Erysipelotrichales']
# ['nan', 'Retroviridae']
# ['nan', 'inner ear cancer']
# ['sarcoma, breast, leukaemia and adrenal gland syndrome', 'SBLA syndrome', 'Li-Fraumeni Familiar cancer Susceptibility syndrome', 'LFS', 'Li-Fraumeni syndrome']
# ['verrucous carcinoma of the esophagus', 'verrucous carcinoma of oesophagus', 'verrucous carcinoma of esophagus', 'oesophagus verrucous carcinoma', 'esophagus verrucous carcinoma']
# ['vaginal tubular adenoma', 'vaginal tubulovillous adenoma']
# ['nan', 'mononuclear cell']
# ['nan', 'marginal zone B cell of spleen']
# ['nan', 'subacute delirium']
# ['nan', 'Abnormal immunoglobulin level']
# ['RP34', 'retinitis pigmentosa 34']
# ['RP60', 'retinitis pigmentosa 60']
# ['RP24', 'retinitis pigmentosa 24']
# ['RP6', 'retinitis pigmentosa 6']
# ['RP3', 'retinitis pigmentosa 3']
# ['RP69', 'retinitis pigmentosa 69']
# ['RP2', 'retinitis pigmentosa 2']
# ['nan', 'retinitis pigmentosa Y-linked']
# ['RP23', 'retinitis pigmentosa 23']
# ['nan', 'retinitis pigmentosa with or without situs inversus']
# ['deficiency, Laki-Lorand factor', 'Hereditary factor XIII deficiency disease', 'Factor XIII deficiency disease', 'factor XIII deficiency']
# ['inner ear infection', 'otitis interna']
# ['nan', 'obsolete pediatric synovial sarcoma']
# ['nan', 'oxygen molecular entity']
# ['nan', 'Narrow face']
# ['nan', 'Abnormality of the face']
# ['nan', 'Abnormal mandible morphology']
# ['nan', 'Malar flattening']
# ['nan', 'Small face']
# ['nan', 'Retrognathia']
# ['nan', 'Leptotrombidium']
# ['Citrus sinensis fruit allergy', 'orange allergy']
# ['nan', 'gastrointestinal allergy']
# ['nan', 'fruit allergy']
# ['nan', 'metal allergy']
# ['Malus domestica fruit allergy', 'apple allergy']
# ['Prunus avium fruit allergy', 'cherry allergy']
# ['Cucumis melo fruit allergy', 'melon allergy']
# ['Ziziphus mauritiana fruit allergy', 'Indian plum allergy']
# ['Prunus armeniaca fruit allergy', 'apricot allergy']
# ['nan', 'drug allergy']
# ['neoplasm of hilus of lung', 'lung Hilum tumor', 'hilar lung neoplasm']
# ['Mevalonate Kinase Deficiency', 'mevalonic aciduria']
# ['nan', 'hyperphosphatemia']
# ['HYPOMAGNESEMIA-HYPOKALEMIA, PRIMARY RENOTUBULAR, WITH HYPOCALCIURIA', 'Gitelman syndrome']
# ["Searle's ulcer", 'Searl ulcer', 'Mossman ulcer', 'Daintree ulcer', 'Bairnsdale ulcer', 'Buruli ulcer disease']
# ['nan', 'juvenile myelomonocytic leukemia']
# ['nan', 'obsolete arachnodactyly']
# ['Germinal Cell Aplasia', 'DEL CASTILLO SYNDROME', 'Sertoli cell-only syndrome']
# ['nan', 'lissencephaly']
# ['periventricular heterotopia', 'periventricular nodular heterotopia']
# ['sudden unexplained nocturnal death syndrome', 'SUNDS', 'Pokkuri death syndrome', 'Dream disease', 'Brugada type idiopathic ventricular fibrillation', 'Bangungut', 'Brugada syndrome']
# ['leiomyosarcoma of the breast', 'breast leiomyosarcoma']
# ['malignant tumor of endocardium', 'malignant neoplasm of endocardium', 'malignant Endocardial tumor', 'endocardium cancer']
# ['relapsed tumor of adult brain', 'obsolete recurrent adult brain tumor']
# ['nan', 'ovarian clear cell adenofibroma']
# ['Mixed Phenotype Acute Leukemia with t(9;22)(q34.1;q11.2); BCR-ABL1', 'mixed phenotype acute leukemia with BCR-ABL1']
# ['Mixed Phenotype Acute Leukemia with t(v;11q23.3); MLL Rearranged', 'mixed phenotype acute leukemia with MLL rearranged']
# ['nan', 'glutatione synthetase deficiency with 5-oxoprolinuria']
# ['nan', 'generalized lymphatic anomaly']
# ['lymphatic malformation-7', 'central conducting lymphatic anomaly']
# ['nan', 'mixed phenotype acute leukemia, T/myeloid']
# ['nan', 'mixed phenotype acute leukemia, B/myeloid']
# ['nan', 'obsolete hepatitis virus related hepatocellular carcinoma']
# ['Congenital Telangiectatic Erythema syndrome', 'Bloom-Torre-Machacek syndrome', 'Bloom syndrome']
# ['Tritanopia', 'Tritan defect', 'blue color blindness']
# ['Hench-Rosenberg syndrome', "Hench's syndrome", 'palindromic rheumatism']
# ["Patau's syndrome", 'trisomy 13', 'D1 Trisomy', 'Patau syndrome']
# ['nan', 'hypopigmentation of eyelid']
# ['nan', 'obsolete color vision defect']
# ['nan', 'hypertrichosis of eyelid']
# ['renal sclerosis', 'nephrosclerosis']
# ['nan', 'pleuropulmonary blastoma']
# ['nan', 'obsolete plasma cell myeloma PTLD']
# ['relapsed adenocarcinoma of the esophagus', 'obsolete esophageal adenocarcinoma recurrent']
# ['nan', 'Paracoccidioides brasiliensis']
# ['nan', 'Lacazia loboi']
# ["adenocarcinoma of bartholin's gland", "adenocarcinoma of the Bartholin's gland", 'Bartholin gland adenocarcinoma', "Bartholin's gland adenocarcinoma"]
# ['nan', 'Coloboma']
# ['nan', 'Optic disc coloboma']
# ['nan', 'Pigmentary retinopathy']
# ['nan', 'Abnormal optic nerve morphology']
# ['recurrent NSCLC', 'obsolete non small cell lung cancer recurrent']
# ['PLAT', 'thyroid hyalinizing trabecular adenoma']
# ['nan', 'sesquiterpene lactone']
# ['nan', 'obsolete localized resectable neuroblastoma']
# ['Anaplasmosis (disorder)', 'obsolete bovine anaplasmosis']
# ['prostate phyllodes tumour', 'prostate phyllodes tumor', 'benign prostate phyllodes tumour', 'benign Phyllodes neoplasm of the prostate', 'Phyllodes neoplasm of the prostate', 'benign prostate phyllodes tumor']
# ['sarcoma of Heart', 'cardiac sarcoma', 'heart sarcoma']
# ['nan', 'sclerosteosis']
# ['nan', 'scapuloperoneal myopathy']
# ['reticulate acropigmentation of Dohi', 'dyschromatosis symmetrica hereditaria']
# ['isolated congenital sclerocornea', 'sclerocornea']
# ['RAPK', 'reticulate acropigmentation of Kitamura']
# ['nan', 'idiopathic scoliosis']
# ['reticular pigment anomaly of flexures', 'dark dot disease', 'Dowling-Degos disease']
# ['fetal face syndrome', 'acral dysostosis with facial and genital abnormalities', 'Robinow dwarfism', 'Robinow syndrome']
# ['autosomal dominant limb-girdle muscular dystrophy type 1C', 'rippling muscle disease 2']
# ["Ivemark's syndrome", 'renal-hepatic-pancreatic dysplasia']
# ['cardiomyopathy familial hypertrophic 26', 'CMH26', 'hypertrophic cardiomyopathy 26']
# ['cardiomyopathy familial hypertrophic 15', 'CMH15', 'hypertrophic cardiomyopathy 15']
# ['nan', 'obsolete hypertrophic cardiomyopathy 19']
# ['cardiomyopathy familial hypertrophic 17', 'CMH17', 'hypertrophic cardiomyopathy 17']
# ['cardiomyopathy familial hypertrophic 14', 'CMH14', 'hypertrophic cardiomyopathy 14']
# ['cardiomyopathy familial hypertrophic 16', 'CMH16', 'hypertrophic cardiomyopathy 16']
# ['cardiomyopathy familial hypertrophic 20', 'CMH20', 'hypertrophic cardiomyopathy 20']
# ['LCA6', 'Leber congenital amaurosis 6']
# ['cardiomyopathy familial hypertrophic 18', 'CMH18', 'hypertrophic cardiomyopathy 18']
# ['cardiomyopathy familial hypertrophic 25', 'CMH25', 'hypertrophic cardiomyopathy 25']
# ['nan', 'cephalosporin']
# ['nan', 'obsolete Avulavirus infectious disease']
# ['nan', 'infiltrating bladder lymphoepithelioma-like carcinoma']
# ['nan', 'arachnid borne transmission']
# ['stomach adenocarcinoma', 'adenocarcinoma of stomach', 'gastric adenocarcinoma']
# ['adult anaplastic (malignant) meningioma', 'WHO grade III meningioma', 'obsolete adult malignant meningioma']
# ['nan', 'oxolanes']
# ['nan', 'obsolete ovarian dermoid cyst with leiomyosarcoma']
# ['nan', 'Lipid accumulation in hepatocytes']
# ['neuronal and mixed neuronal-glial tumor (morphologic abnormality)', 'neuronal and Glio-neuronal tumor', 'obsolete neuronal and glio-neuronal neoplasm']
# ['female reproductive endometrioid neoplasm', 'endometrioid tumor', 'endometrioid neoplasm', 'female reproductive endometrioid cancer']
# ['nan', 'skin of trunk']
# ['nan', 'retroperitoneal hemangiopericytoma']
# ['nan', 'Hortaea']
# ['postpartum drug dependence', 'drug dependence of mother with delivery', 'Pregnancy and drug dependence (disorder)', 'Pregnancy and drug dependence', 'Drug dependence, antepartum', 'obsolete Drug dependence complicating pregnancy, childbirth, or the puerperium']
# ['nan', 'diisocyanate']
# ['nan', 'Multicrustacea']
# ['Obliterative bronchiolitis', 'Bronchiolitis fibrosa obliterans', 'Bronchiolitis exudativa', 'bronchiolitis obliterans']
# ["Dubowitz's syndrome", 'Dubowitz syndrome']
# ['nan', 'hypohidrotic ectodermal dysplasia']
# ['familial infantile type osteochondrosis deformans tibiae', 'Blount disease', "Blount's disease"]
# ["Leber's disease", "Leber's congenital amaurosis", "Leber's amaurosis", 'LCA', 'Leber congenital amaurosis']
# ['nan', 'Cellia']
# ['nan', 'Lyssavirus']
# ['secondary malignant neoplasm of retroperitoneum or peritoneum NOS (disorder)', 'secondary malignant neoplasm of retroperitoneum and peritoneum (disorder)', 'obsolete secondary malignant neoplasm of retroperitoneum and peritoneum']
# ['mixed epithelial tumour of ovary', 'Ovarian mixed epithelial tumour', 'Ovarian mixed epithelial tumor', 'mixed epithelial tumor of ovary']
# ['Pierre Robin Malformation', 'Piere-Robin syndrome', 'Weissenbacher-Zweymuller syndrome']
# ['Hemangiopericytic neoplasm', 'hemangiopericytic tumor']
# ['nan', 'Hypotonia']
# ['nan', 'Ataxia']
# ['nan', 'Spasticity']
# ['nan', 'Talaromyces']
# ['nan', 'Toxocara']
# ['nan', 'Anisakis']
# ['nan', 'Anisakis simplex']
# ['nan', 'Anisakidae']
# ['nan', 'ovarian dysfunction']
# ['calculus of ureter', 'Ureteric stone', 'Ureteric calculus', 'ureterolithiasis']
# ['nan', 'pulp erosion']
# ['malignant melanoma of anus', 'anal melanoma', 'malignant anus melanoma']
# ['testicular Yolk Sac neoplasm', 'testicular yolk sac tumor']
# ['nan', 'Abnormality of muscle size']
# ['Undifferentiated pediatric Oligodendroglioma', 'obsolete anaplastic childhood oligodendroglioma']
# ['Unspecified disease due to mycobacteria', 'Mycobacterium infection, unspecified (disorder)', 'Mycobacterial disease NOS (disorder)', 'Mycobacterial disease', 'Mycobacterial Infection', 'Infection due to mycobacteria', 'obsolete Mycobacterium infectious disease']
# ['deficiency of dextrin', 'deficiency of debranching enzyme', 'amylo 1,6 glucosidase deficiency', 'Glycogen storage disease, type III', 'Glycogen storage disease 3', 'glycogen storage disease III']
# ['mixed cell type renal Wilms tumour', 'mixed cell type renal Wilms tumor', "mixed cell type kidney Wilms' tumour", "mixed cell type kidney Wilms' tumor"]
# ['rod monochromatism 1', 'rod monochromacy 1', 'RMCH1', 'Pingelapese blindness', 'ACHM3', 'ACHM1', 'achromatopsia 3']
# ['dilated cardiomyopathy with ataxia', 'MGCA5', 'MGA5', 'DCMA syndrome', 'DCMA', '3-methylglutaconic aciduria type V', '3-methylglutaconic aciduria type 5']
# ['ACHM7', 'achromatopsia 7']
# ['MGA1', 'MGA type I', '3MG-CoA hydratase deficiency', '3-methylglutaconyl-CoA hydratase deficiency', '3-methylglutaconic aciduria type I', '3-methylglutaconic aciduria type 1']
# ['LCA9', 'Leber congenital amaurosis 9']
# ['infantile optic atrophy with chorea and spastic paraplegia', 'autosomal recessive optic atrophy type 3', 'autosomal recessive optic atrophy plus syndrome', 'MGA3', 'Iraqi-Jewish optic atrophy plus', 'Costeff syndrome', 'Costeff optic atrophy syndrome', '3-methylglutaconic aciduria type III', '3-methylglutaconic aciduria type 3']
# ['MGCA7', 'MGA7', 'MEGCANN', '3-methylglutaconic aciduria type VII', '3-methylglutaconic aciduria type 7', '3-methylglutaconic aciduria with cataracts, neurologic involvement and neutropenia']
# ['rod monochromatism 2', 'rod monochromacy 2', 'RMCH2', 'ACHM2', 'achromatopsia 2']
# ['MGCA6', 'MEGDEL syndrome', 'MEGDEL', '3-methylglutaconic aciduria type 6', '3-methylglutaconic aciduria with deafness, encephalopathy, and Leigh-like syndrome']
# ['MGCA4', 'MGA4', 'MGA type IV', '3-methylglutaconic aciduria type IV', '3-methylglutaconic aciduria type 4']
# ['total Mari type hypotrichosis,', 'hypotrichosis, localized, autosomal recessive 2', 'Lah2', 'Hypt7', 'hypotrichosis 7']
# ['Hypt10', 'hypotrichosis 10']
# ['Hypt9', 'hypotrichosis 9']
# ['hypotrichosis simplex of the scalp 2', 'Hypt3', 'Htss2', 'hypotrichosis 3']
# ['Hypt12', 'hypotrichosis 12']
# ['Hypt11', 'hypotrichosis 11']
# ['Muhh2', 'Marie Unna Hereditary Hypotrichosis 2', 'Hypt5', 'hypotrichosis 5']
# ['Muhh1', 'Marie Unna Hereditary Hypotrichosis 1', 'Hypt4', 'Hypotrichosis, Marie Unna Type, 1', 'hypotrichosis 4']
# ['hypotrichosis, localized, autosomal recessive 3', 'Lah3', 'Hypt8', 'hypotrichosis 8']
# ['autosomal recessive localized hypotrichosis', 'Monilethrix-like hypotrichosis', 'Lah1', 'Hypt6', 'Hypotrichosis, Localized, Autosomal Recessive 1', 'hypotrichosis 6']
# ['Colloidal cystadenocarcinoma of the appendix', 'appendix mucinous cystadenocarcinoma']
# ['nan', 'obsolete glomerular vascular disorder']
# ['nan', 'gland']
# ['nan', 'Anemiaceae']
# ['nan', 'Schizaeales']
# ['basosquamous cell carcinoma', 'Metatypical carcinoma', 'Basisquamous cell carcinoma', 'basosquamous carcinoma']
# ['melanoma of Uvea', 'uveal melanoma']
# ['nan', 'tract of brain']
# ['nan', 'transient tic disorder']
# ['nan', 'filamentary keratitis']
# ['nan', 'cell type benign neoplasm']
# ['nan', 'male reproductive organ benign neoplasm']
# ['nan', 'organ system benign neoplasm']
# ['nan', 'immune system cancer']
# ['nan', 'triple-receptor negative breast cancer']
# ['nan', 'breast benign neoplasm']
# ['nan', 'female reproductive organ benign neoplasm']
# ['nan', 'Her2-receptor negative breast cancer']
# ['nan', 'vestibular gland benign neoplasm']
# ['nan', 'endocrine organ benign neoplasm']
# ['inability to comprehend language', 'aphasia']
# ['nan', 'right lower quadrant abdominal tenderness']
# ['nan', 'adult failure to thrive']
# ['sore throat', 'throat pain']
# ['cephalalgia', 'headache']
# ['gas production', 'gas', 'flatulence']
# ['nan', 'mixed incontinence (female) (male)']
# ['nan', 'hemorrhage from throat']
# ['nan', 'left lower quadrant abdominal swelling']
# ['nan', 'head swelling']
# ['secondary malignant neoplasm of gallbladder (disorder)', 'metastatic tumor to the gallbladder', 'obsolete metastatic neoplasm to the gallbladder']
# ['nan', 'obsolete primary Neisseriaceae infectious disease']
# ['nan', 'Positional foot deformity']
# ['nan', 'Eukaryota']
# ['FNEPPK2', 'focal nonepidermolytic palmoplantar keratoderma 2']
# ['autosomal dominant focal non-epidermolytic palmoplantar keratoderma with plantar blistering', 'PPKNEFD', 'focal or diffuse nonepidermolytic palmoplantar keratoderma']
# ['SHFYNG', 'PWLS', 'MAGEL2-related Prader-Willi-like syndrome', 'MAGEL2-related PWLS', 'Schaaf-Yang syndrome']
# ['KOS', 'Kagami-Ogata syndrome']
# ['maternal uniparental disomy of chromosome 20', 'maternal UPD(20)', 'UPD(20)mat', 'MBCS', 'Mulchandani-Bhoj-Conlin syndrome']
# ['cryptophthalmos', 'cryptophthalmia']
# ['nan', 'Temple syndrome']
# ['incomplete cryptophthalmos', 'partial cryptophthalmia']
# ['nan', 'complete cryptophthalmia']
# ['unilateral or bilateral isolated cryptophthalmos', 'CRYPTOP', 'isolated cryptophthalmia']
# ['Gas bacillus infection', 'gas gangrene']
# ['nan', 'Oryzomys palustris']
# ['nan', 'slowing of urinary stream']
# ['nan', 'abnormal chest sound']
# ['nan', 'disruptions of 24-hour sleep-wake cycle']
# ['nan', 'sleep related movement disorder']
# ['nan', 'hypersomnia']
# ['nan', 'overflow incontinence']
# ['nan', 'dysfunctions associated with sleep stages']
# ['nan', 'hypersomnia with sleep apnea']
# ['nan', 'sleep apnea']
# ['nan', 'extravasation of urine']
# ['nan', 'choroid disease']
# ['Congenital hypogammaglobulinaemia', 'congenital hypogammaglobulinemia']
# ['von Hippel-Lindau syndrome', 'Hippel Lindau syndrome', 'von Hippel-Lindau disease']
# ['Rheumatic heart failure', 'Congestive rheumatic heart failure', 'rheumatic congestive heart failure']
# ['nan', 'obsolete immunodeficiency with increased IgM']
# ['Selective immunoglobulin G deficiency', 'Selective deficiency of IgG', 'Selective Immunoglobulin G Subclass deficiency', 'Selective IgG Immunodeficiency', 'Immunoglobin G subclass deficiency', 'selective IgG deficiency disease']
# ['Neurolipocytoma', 'central neurocytoma']
# ['Bruton-type agammaglobulinemia', "Bruton's type agammaglobulinemia", "Bruton's agammaglobulinaemia", "Bruton's Sex-Linked Agammaglobulinemia", 'Bruton disease', 'Bruton agammaglobulinemia tyrosine kinase deficiency', 'BTK deficiency', 'X-linked agammaglobulinemia']
# ['Monilial vulvovaginitis', 'Candidiasis of vulva and vagina', 'Candidal vulvovaginitis', 'Candidal cervix', 'vulvovaginal candidiasis']
# ['nan', 'Culicoidini']
# ['nan', 'Martellivirales']
# ['nan', 'sensory ganglion']
# ['transitional cell carcinoma of prostate', 'prostate transitional cell carcinoma']
# ['nan', 'Nidovirales']
# ['nan', 'caseation']
# ...
# ['autosomal dominant non-syndromic intellectual disability 4', 'autosomal dominant mental retardation 4', 'MRD4', 'autosomal dominant intellectual developmental disorder 4']
# ['autosomal dominant non-syndromic intellectual disability 1', 'autosomal dominant mental retardation 1', 'MRD1', 'autosomal dominant intellectual developmental disorder 1']
# ['autosomal dominant non-syndromic intellectual disability 7', 'autosomal dominant mental retardation 7', 'MRD7', 'DYRK1A syndrome', 'autosomal dominant intellectual developmental disorder 7']
# ['autosomal dominant non-syndromic intellectual disability 6', 'autosomal dominant mental retardation 6', 'MRD6', 'autosomal dominant intellectual developmental disorder 6']
# ['nan', 'intravascular angioleiomyoma']
# ['nan', 'curator inference from book']
# ['Reticulosarcoma of intrathoracic lymph nodes (disorder)', 'Reticulosarcoma of intrathoracic lymph nodes', 'obsolete reticulosarcoma involving intrathoracic lymph nodes']
# ['nan', 'obsolete primary ectopic meningioma']
# ['mother-to-child transmission', 'congenital transmission']
# ['squamous cell carcinoma of external ear', 'Epidermoid carcinoma of the External ear', 'external ear squamous cell carcinoma']
# ['Senile naevus of skin', 'Senile hemangioma', 'senile angioma']
# ['nan', 'malignant epithelial mesothelioma']
# ['familial febrile convulsions 11', 'FEB11', 'familial febrile seizures 11']
# ['generalized epilepsy with febrile seizures plus type 1', 'generalised epilepsy with febrile seizures plus type 1', 'generalised epilepsy with febrile seizures plus 1', 'GEFSP1', 'GEFS+1', 'generalized epilepsy with febrile seizures plus 1']
# ['familial febrile convulsions 1', 'FEB1', 'familial febrile seizures 1']
# ['generalized epilepsy with febrile seizures plus type 6', 'generalised epilepsy with febrile seizures plus type 6', 'generalised epilepsy with febrile seizures plus 6', 'GEFSP6', 'GEFS+6', 'generalized epilepsy with febrile seizures plus 6']
# ['familial febrile convulsions 4', 'FEB4', 'familial febrile seizures 4']
# ['familial febrile convulsions 10', 'FEB10', 'familial febrile seizures 10']
# ['familial febrile convulsions 6', 'FEB6', 'familial febrile seizures 6']
# ['generalized epilepsy with febrile seizures plus type 9', 'generalised epilepsy with febrile seizures plus type 9', 'generalised epilepsy with febrile seizures plus 9', 'GEFSP9', 'GEFS+9', 'generalized epilepsy with febrile seizures plus 9']
# ['familial febrile convulsions 9', 'FEB9', 'familial febrile seizures 9']
# ['familial febrile convulsions 5', 'FEB5', 'familial febrile seizures 5']
# ['nan', 'polycyclic compound']
# ['nan', 'obsolete tuberculous bronchiectasis']
# ['nan', 'autosomal recessive intellectual developmental disorder 63']
# ['Intellectual developmental disorder, autosomal recessive 62', 'glycosylphosphatidylinositol biosynthesis defect 16']
# ['nan', 'autosomal recessive intellectual developmental disorder 64']
# ['nan', 'autosomal recessive intellectual developmental disorder 58']
# ['nan', 'autosomal recessive intellectual developmental disorder 65']
# ['nan', 'autosomal recessive intellectual developmental disorder 67']
# ['nan', 'autosomal recessive intellectual developmental disorder 60']
# ['nan', 'autosomal recessive intellectual developmental disorder 66']
# ['nan', 'autosomal recessive intellectual developmental disorder 59']
# ['nan', 'autosomal recessive intellectual developmental disorder 68']
# ['nan', 'mucinoses']
# ['Serum hepatitis', 'hepatitis B infection', 'chronic hepatitis B', 'hepatitis B']
# ['relapsed cancer of the Thyroid', 'obsolete recurrent thyroid carcinoma']
# ['nan', 'uterine ligament endometrioid adenocarcinoma']
# ['nan', 'eunuchism']
# ['sialidosis', 'Mucolipidosis type I', 'glycoproteinosis']
# ['nan', 'genic_downstream_transcript_variant']
# ['nan', 'genic_upstream_transcript_variant']
# ['paraurethral gland carcinoma', 'carcinoma of the paraurethral gland', 'Skene gland carcinoma']
# ['cardiac fibrosarcoma', 'Fibrosarcoma of the Heart', 'heart fibrosarcoma']
# ['nan', 'intracranial berry aneurysm 4']
# ['nan', 'intracranial berry aneurysm 1']
# ['Amelogenesis imperfecta, hypomaturation type, IIA6', 'amelogenesis imperfecta type 2A6']
# ['nan', 'intracranial berry aneurysm 3']
# ['nan', 'intracranial berry aneurysm 5']
# ['nan', 'anauxetic dysplasia 3']
# ['nan', 'intracranial berry aneurysm 2']
# ['nan', 'intracranial berry aneurysm 6']
# ['nan', 'anauxetic dysplasia 2']
# ['nan', 'granulomatous hepatitis']
# ['nan', 'osteoarthritis susceptibility 1']
# ['nan', 'uterine corpus epithelioid leiomyoma']
# ['nan', 'schistosomiasis']
# ['nan', 'uterine corpus myxoid leiomyoma']
# ['nan', 'uterine corpus dissecting leiomyoma']
# ['Intramural leiomyoma of uterus', 'uterus interstitial leiomyoma']
# ['nan', 'uterine corpus lipoleiomyoma']
# ['nan', 'obsolete mitotically active variant uterine corpus leiomyoma']
# ['uterine Corpus Symplastic leiomyoma', 'uterine corpus bizarre leiomyoma']
# ['food hypersensitivity', 'food allergy']
# ['nan', 'Otophysi']
# ['nan', 'Actinopteri']
# ['nan', 'Clupeocephala']
# ['nan', 'Cypriniphysae']
# ['ocular discharge', 'eye discharge']
# ['fixed pupils', 'fixed pupil']
# ['nan', 'facial paralysis']
# ['nan', 'extreme fatigue']
# ['nan', 'fixed dilated pupils']
# ['nan', 'flaccid paralysis']
# ['fluctuation of heart rate', 'irregular heartbeat', 'heart rhythm symptom', 'dysrhythmia', 'abnormal heart rhythm', 'abnormal heart beat', 'arrhythmia']
# ['nan', 'eczema']
# ['nan', 'internal ear']
# ['vertebral disc disease', 'lumbar disc degeneration', 'intervertebral disc degeneration', 'cervical disc degenerative disease', 'degenerative disc disease']
# ['peroxisomal disorder', 'peroxisomal disease']
# ['nan', 'gastrointestinal lymphoma']
# ['nan', 'obsolete malignant non-epithelial hepatic and intrahepatic bile duct neoplasm']
# ['nan', 'hepatopulmonary syndrome']
# ['congenital iron overload', 'cerebrohepatorenal syndrome', 'Zellweger syndrome']
# ['Fibroma of the Liver', 'liver fibroma']
# ['Lymphoma of Liver', 'liver lymphoma']
# ['nan', 'Negarnaviricota']
# ['nan', 'adult malignant mesenchymoma']
# ['nan', 'parathyroid oncocytic adenoma']
# ['Brain degeneration', 'cerebral degeneration']
# ['intestinal infection due to enterotoxigenic E. coli', 'Enterotoxigenic Escherichia coli gastrointestinal tract infection (disorder)', 'Enterotoxigenic Escherichia coli gastrointestinal tract infection', 'obsolete enterotoxigenic Escherichia coli infectious disease']
# ['intestinal infection due to enterohemorrhagic E. coli', 'Verotoxigenic Escherichia coli gastrointestinal tract infection (disorder)', 'Verotoxigenic Escherichia coli gastrointestinal tract infection', 'obsolete enterohemorrhagic Escherichia coli infectious disease']
# ['nan', 'chronic tubotympanic suppurative otitis media']
# ['nan', 'chronic apical periodontitis']
# ['nan', 'keratomalacia']
# ['Puumala virus nephropathy', 'Hemorrhagic nephrosonephritis', 'Hemorrhagic fever, Russian', 'HFRS', 'Hantavirus hemorrhagic fever with renal syndrome']
# ['trachoma dubium', 'active stage trachoma', 'trachoma']
# ['Epizootic stomatitis', 'obsolete foot and mouth disease']
# ['nan', 'obsolete Chlamydophila infectious disease']
# ['vitamin A deficiency with keratomalacia (disorder)', 'obsolete vitamin A deficiency with keratomalacia']
# ['Lyssa', 'rabies']
# ['chlamydial disease', 'Chlamydial Infection', 'Chlamydia trachomatis infectious disease', 'chlamydia']
# ['psittacosis', 'ornithosis']
# ['nan', 'mixed cell adenoma']
# ['nan', 'Amarillovirales']
# ["Hodgkin's disease, lymphocytic-histiocytic predominance involving lymph nodes of head, face, and neck", "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face and/or neck (disorder)", "Hodgkin's disease, lymphocytic-histiocytic predominance of lymph nodes of head, face and neck (disorder)", "Hodgkin's disease, lymphocytic-histiocytic predominance involving lymph nodes of head, face and neck", "obsolete Hodgkin's lymphoma, lymphocytic-histiocytic predominance involving lymph nodes of head, face, and neck"]
# ['nan', 'giddiness']
# ['nan', 'darkening of skin']
# ['nan', 'confusion']
# ['nan', 'blurred vision']
# ['nan', 'deafness']
# ['nan', 'crinkle']
# ['bilirubin encephalopathy', 'kernicterus']
# ['nan', 'susceptibility to strabismus']
# ['nan', 'susceptibility to dyslexia 1']
# ['nan', 'Mycoplasmoides']
# ['nan', 'chromosomal rearrangement inheritance']
# ['nan', 'chromosomal deletion inheritance']
# ['nan', 'chromosomal duplication inheritance']
# ['nan', 'Necator']
# ['pediatric renal cell carcinoma', 'childhood kidney cell carcinoma']
# ['nan', 'Orthohantavirus sinnombreense']
# ['nan', 'mucinous tubular and spindle renal cell carcinoma']
# ['nan', 'cefotiam']
# ['nan', 'pseudohypoaldosteronism']
# ['nan', 'myocardium']
# ['nan', 'epicardium']
# ['nan', 'Abnormal cerebral white matter morphology']
# ['nan', 'Spinocerebellar tract degeneration']
# ['nan', 'pontocerebellar hypoplasia type 10']
# ['nan', 'pontocerebellar hypoplasia type 2D']
# ['nan', 'pontocerebellar hypoplasia type 4']
# ['nan', 'pontocerebellar hypoplasia type 7']
# ['nan', 'pontocerebellar hypoplasia type 9']
# ['nan', 'pontocerebellar hypoplasia type 2E']
# ['nan', 'pontocerebellar hypoplasia type 8']
# ['nan', 'pontocerebellar hypoplasia type 5']
# ['nan', 'pontocerebellar hypoplasia type 6']
# ['nan', 'pontocerebellar hypoplasia type 3']
# ['nan', 'obsolete environmental illness']
# ['pulmonary heart disease', 'cardiopulmonary disease', 'Cor pulmonale']
# ['Congenital leukocyte adherence deficiency', 'leukocyte adhesion deficiency']
# ['nan', 'mucosa']
# ['nan', 'throat']
# ['Thymoma, mixed type, malignant', 'malignant type AB thymoma']
# ['nan', 'bladder papillary clear cell adenocarcinoma']
# ['Infection due to Erysipelothrix rhusiopathiae', 'Infection due to E. rhusiopathiae', 'obsolete Erysipelothrix rhusiopathiae infectious disease']
# ['disease of capillaries', 'capillary disease']
# ['pulmonary African histoplasmosis (disorder)', 'obsolete Histoplasma duboisii pneumonia']
# ['nan', 'black piedra']
# ['respiratory distress syndrome of newborn', 'pulmonary hypoperfusion syndrome of newborn', 'pulmonary hyaline membrane disease', 'hyaline membrane disease', 'Neonatal respiratory Distress syndrome', 'HMD - Hyaline membrane disease', 'newborn respiratory distress syndrome']
# ['mesoectodermal dysplasia', 'Chondroectodermal dysplasia', 'Ellis-Van Creveld syndrome']
# ['Infective myositis (disorder)', 'Infective myositis', 'Infective Myositis', 'obsolete infectious myositis']
# ['Sponge kidney', 'Medullary sponge kidney (disorder)', 'Medullary Sponge kidney', 'obsolete medullary sponge kidney']
# ['Gonococcal salpingitis', 'chronic gonococcal salpingitis']
# ['medullary cystic kidney', 'medullary cystic disease', 'nephronophthisis']
# ['nan', 'L-phenylalanine derivative']
# ['nan', 'metal allergen']
# ['nan', 'Rickettsia japonica']
# ['cystic hypersecretory carcinoma of the breast', 'cystic hypersecretory duct carcinoma of the breast', 'breast cystic hypersecretory carcinoma']
# ['familial type 3 hyperlipoproteinemia', 'familial hypercholesterolaemia with hyperlipaemia', 'carbohydrate induced hyperlipemia', 'Remnant hyperlipidemia', 'hyperlipoproteinemia type III']
# ['calculus of gallbladder and bile duct with acute and chronic cholecystitis, with obstruction', 'obsolete calculus of gallbladder and bile duct with acute and chronic cholecystitis']
# ['nan', 'Quintoviricetes']
# ['generalized tuberculosis', 'acute miliary tuberculosis', 'Tuberculosis miliaris disseminata', 'Disseminated tuberculosis', 'miliary tuberculosis']
# ['nan', 'Abnormal gastrointestinal motility']
# ['nan', 'neural crest-derived structure']
# ['nan', 'structure with developmental contribution from neural crest']
# ['nan', 'germ layer / neural crest']
# ['nan', 'testicular fibroma']
# ['nan', 'carbohydrate']
# ['optic neuropathy', 'optic nerve disorder', 'disorder of the second nerve', 'optic nerve disease']
# ['nonencapsulated sclerosing carcinoma', 'diffuse sclerosing PTC', 'Papillary carcinoma, diffuse sclerosing', 'Nonencapsulated Sclerosing neoplasm', 'Diffuse sclerosing papillary thyroid cancer (DSPTC)', 'Diffuse Sclerosing Variant Thyroid Gland Papillary Carcinoma', 'diffuse sclerosing papillary thyroid carcinoma']
# ['nan', 'gallbladder papillomatosis']
# ['nan', 'obsolete refraction or accommodation disorder']
# ['recessive ataxia of Beauce', 'autosomal recessive ataxia, Beauce type', 'SYNE1-related autosomal recessive cerebellar ataxia', 'SCAR8', 'Autosomal recessive cerebellar ataxia type 1', 'ARCA1', 'autosomal recessive spinocerebellar ataxia 8']
# ['SCAR22', 'autosomal recessive spinocerebellar ataxia 22']
# ['autosomal recessive spinocerebellar ataxia-blindness-hearing loss syndrome', 'autosomal recessive spinocerebellar ataxia-blindness-deafness syndrome', 'autosomal recessive spinocerebellar ataxia type 3', 'SCAR3', 'SCABD', 'autosomal recessive spinocerebellar ataxia 3']
# ['combined D-2-hydroxyglutaric aciduria and L-2-hydroxyglutaric aciduria', 'combined D-2-hydroxyglutaric acidemia and L-2-hydroxyglutaric acidemia', 'combined D,L-2-hydroxyglutaric aciduria', 'D,L-2-hydroxyglutaric aciduria', 'D,L-2-hydroxyglutaric acidemia', 'D,L-2-HGA', 'combined D-2- and L-2-hydroxyglutaric aciduria']
# ['distal arthrogryposis type IID', 'arthrogryposis-severe scoliosis syndrome', 'DAIID', 'DA4', 'distal arthrogryposis type 4']
# ['spinocerebellar ataxia with saccadic intrusions', 'spinocerebellar ataxia 24', 'autosomal recessive cerebellar ataxia-saccadic intrusion syndrome', 'SCASI', 'SCAR4', 'SCA24', 'autosomal recessive spinocerebellar ataxia 4']
# ['infantile-onset autosomal recessive nonprogressive cerebellar ataxia', 'autosomal recessive spinocerebellar ataxia type 6', 'SCAR6', 'autosomal recessive spinocerebellar ataxia 6']
# ['SCAR27', 'autosomal recessive spinocerebellar ataxia 27']
# ['autosomal recessive cerebellar ataxia-epilepsy-intellectual disability syndrome due to TUD deficiency', 'SCAR23', 'autosomal recessive spinocerebellar ataxia 23']
# ['SCAR24', 'autosomal recessive spinocerebellar ataxia 24']
# ['nan', 'Pulmonary infiltrates']
# ['nan', 'Abnormal renal pelvis morphology']
# ['nan', 'Fetal pyelectasis']
# ['nan', 'Dilatation of the renal pelvis']
# ['secondary malignant neoplasm of kidney (disorder)', 'secondary malignant neoplasm of kidney', 'metastatic neoplasm to the kidney', 'metastasis to kidney', 'obsolete metastasis to the kidney']
# ['nan', 'obsolete melancholia']
# ['nan', 'Klebsiella granulomatis']
# ['nan', 'Abnormal cerebral morphology']
# ['Undifferentiated Ependymoma', 'Ependymoma, anaplastic', 'anaplastic ependymoma']
# ['nan', 'macrophage']
# ['nan', 'erythrocyte']
# ['nan', 'phagocyte']
# ['nan', 'platelet']
# ['nan', 'keratinizing barrier epithelial cell']
# ['nan', 'B cell']
# ['nan', 'obsolete primary Anaplasmataceae infectious disease']
# ['nan', 'Pasteurella']
# ['nan', 'apical myocardial infarction']
# ['atopic asthma', 'extrinsic asthma with status asthmaticus', 'extrinsic asthma with acute exacerbation', 'allergic asthma']
# ['Leydig cell neoplasm', 'Leydig cell tumor']
# ['skin appendage tumour', 'neoplasm of the skin Appendage', 'neoplasm of skin with adnexal differentiation', 'epidermal appendage tumor']
# ['relapsed pediatric Ependymoma', 'obsolete relapsed childhood ependymoma']
# ['ampullary small cell carcinoma', 'ampulla of Vater small cell carcinoma']
# ['nan', 'obsolete vulvar tumor of skin appendage origin']
# ['nan', 'Yersinia <enterobacteria>']
# ['nan', 'Filarioidea']
# ['nan', 'Onchocercidae']
# ['Pancreatic Intraductal Neoplasms', 'pancreatic intraductal papillary-mucinous neoplasm']
# ['melanoma of the Iris', 'malignant melanoma of iris', 'malignant iris melanoma']
# ['nan', 'obsolete ovarian mucinous cystic tumor associated with pseudomyxoma peritonei']
# ['antepartum late vomiting of pregnancy', 'obsolete Excessive vomiting starting after 22 completed weeks of gestation']
# ['nan', 'susceptibility to epidermodysplasia verruciformis 1']
# ['nan', 'fallopian tube mucinous tumor']
# ['tumor of the Adrenal gland', 'neoplasm of adrenal gland', 'malignant neoplasm of adrenal gland', 'malignant Adrenal tumor', 'adrenal neoplasm', 'adrenal cancer', 'adrenal gland cancer']

# %% [markdown]
# ## Ontology Matcher

# %%
# Load Dataset
ds = pd.read_csv('emsembl_golph3_dataset.csv', index_col=0)

# %%
# Choose Ontology 
onto = pd.read_csv('MONDO.csv', low_memory=False)
onto_label = 'MONDO'
onto = extract_syn_list(onto)

# Output the updated DataFrame
onto[['synonims_list','Preferred Label']]
# Out:
#                                            synonims_list  \
# 0      [nan, kyphosis-lateral tongue atrophy-myofibri...
# 1             [nan, Jacobsen syndrome, non-human animal]
# 2                   [nan, obsolete apnea, central sleep]
# 3      [46,XX DSD induced by exogenous maternal-deriv...
# 4      [MCOPCB10, microphthalmia, isolated, with colo...
# ...                                                  ...
# 34019  [Fh3, HCHOLA3, low density lipoprotein cholest...
# 34020  [OI with calcification in interosseous membran...
# 34021  [extraventricular neurocytoma (WHO grade II), ...
# 34022  [laminopathy with severe metabolic syndrome an...
# 34023  [OFC5, cleft lip with or without cleft palate,...
#
#                                          Preferred Label
# 0      kyphosis-lateral tongue atrophy-myofibrillar m...
# 1                    Jacobsen syndrome, non-human animal
# 2                          obsolete apnea, central sleep
# 3      obsolete 46,XX disorder of sex development ind...
# 4             microphthalmia, isolated, with coloboma 10
# ...                                                  ...
# 34019        hypercholesterolemia, autosomal dominant, 3
# 34020                     osteogenesis imperfecta type 5
# 34021                       extraventricular neurocytoma
# 34022               laminopathy type Decaudain-Vigouroux
# 34023                                  orofacial cleft 5
#
# [34024 rows x 2 columns]

# %%
# %%time
from tqdm import tqdm
# Ontology Matcher on dataset
ds[onto_label+'_match'] = False

# Iterate over each row in the 'ds' dataframe
for index, row in ds.iterrows():
    # Get the lowercase 'phenotype_description' value for the current row
    phenotype_desc = str(row['phenotype_description']).lower()

    # Iterate over each list in the 'synonims_list' column of the 'onto' dataframe
    for syn_list in onto['synonims_list']:
        # Check if the lowercase 'phenotype_description' value is present in the current list
        if phenotype_desc in [str(syn).lower() for syn in syn_list]:
            # If it is present, set the corresponding row in 'ds' to True
            ds.at[index, onto_label+'_match'] = True
            break  # Exit the loop once a match is found
        #else:
        #    ds.at[index, onto_label+'_match'] = False

# Note: Before running this code, make sure you have a column named 'is_true' in the 'ds' dataframe to store the True values.
#       You may need to initialize this column to False for all rows before the loop.

# %%
ds[['phenotype_description',
    'source_name', onto_label+'_match']]#.head()
# Out:
#                                  phenotype_description         source_name  \
# 0              Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census
# 1                               Hepatobiliary Neoplasm  Cancer Gene Census
# 2                                                   ND  Cancer Gene Census
# 3    Ovarian Endometrioid Adenocarcinoma with Squam...  Cancer Gene Census
# 4                               Uterine Carcinosarcoma  Cancer Gene Census
# ..                                                 ...                 ...
# 451                                     skin carcinoma  Cancer Gene Census
# 452                          Small cell lung carcinoma  Cancer Gene Census
# 453                                soft tissue sarcoma  Cancer Gene Census
# 454                       squamous cell lung carcinoma  Cancer Gene Census
# 455                                  thyroid carcinoma  Cancer Gene Census
#
#      MONDO_match
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ..           ...
# 451         True
# 452         True
# 453         True
# 454         True
# 455         True
#
# [456 rows x 3 columns]

# %% [markdown]
# ## Run Ontology Matching

# %%
ds

# %%
onto.T.head()

# %%
# Iterate over each row in the 'ds' dataframe
def ontology_matcher(ds, ontology, label):
    for index, row in ds.iterrows():
        # Get the lowercase 'phenotype_description' value for the current row
        phenotype_desc = str(row['phenotype_description']).lower()

        # Iterate over each list in the 'synonims_list' column of the 'doid' dataframe
        for onto_index, syn_list in enumerate(ontology['synonims_list']):
            #print(index, syn_list)
            # Check if the lowercase 'phenotype_description' value is present in the current list
            if phenotype_desc in [str(syn).lower() for syn in syn_list]:
                # If it is present, set the corresponding row in 'ds' to True
                ds.at[index, label+'_match'] = True
                ds.at[index, label+'_ClassID'] = ontology['Class ID'].iloc[onto_index]
                ds.at[index, label+'_synonims'] = str(syn_list)#ontology['synonims_list'].iloc[onto_index] 
                break  # Exit the loop once a match is found

# %% [markdown]
# ## MONDO

# %%
# %%time 
# Choose Ontology
mondo = pd.read_csv('MONDO.csv', low_memory=False)
mondo = extract_syn_list(mondo)

ds = pd.read_csv('emsembl_golph3_dataset.csv', index_col=0)
ds[onto_label+'_match'] = False

ontology_matcher(ds, mondo, 'MONDO')
# Note: Before running this code, make sure you have a column named 'is_true' in the 'ds' dataframe to store the True values.
#       You may need to initialize this column to False for all rows before the loop.
# Out:
# CPU times: total: 15.9 s
# Wall time: 18.3 s

# %%
label = 'MONDO'
cols = ['ensembl_gene_id', 'ensembl_gene_id_version', 'ensembl_peptide_id',
        'ensembl_peptide_id_version', 'description', 'chromosome_name',
        'start_position', 'end_position', 'strand', 'band',
        'external_gene_name', 'external_gene_source',
        'percentage_gene_gc_content', 'gene_biotype', 'source', 'version',
        'peptide_version', 'external_synonym', 'phenotype_description',
        'source_name', 'p_value', label+'_match', label+'_ClassID', label+'_synonims']
ds[cols]#.to_csv('golph3_mondo_match.csv')
# Out:
#      ensembl_gene_id ensembl_gene_id_version ensembl_peptide_id  \
# 0    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 1    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 2    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 3    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 4    ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# ..               ...                     ...                ...
# 451  ENSG00000113384      ENSG00000113384.14                NaN
# 452  ENSG00000113384      ENSG00000113384.14                NaN
# 453  ENSG00000113384      ENSG00000113384.14                NaN
# 454  ENSG00000113384      ENSG00000113384.14                NaN
# 455  ENSG00000113384      ENSG00000113384.14                NaN
#
#     ensembl_peptide_id_version  \
# 0            ENSP00000265070.6
# 1            ENSP00000265070.6
# 2            ENSP00000265070.6
# 3            ENSP00000265070.6
# 4            ENSP00000265070.6
# ..                         ...
# 451                        NaN
# 452                        NaN
# 453                        NaN
# 454                        NaN
# 455                        NaN
#
#                                            description  chromosome_name  \
# 0    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 1    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 2    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 3    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 4    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# ..                                                 ...              ...
# 451  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 452  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 453  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 454  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 455  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
#
#      start_position  end_position  strand   band  ...          source version  \
# 0          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 1          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 2          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 3          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 4          32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# ..              ...           ...     ...    ...  ...             ...     ...
# 451        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 452        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 453        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 454        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
# 455        32124716      32174319      -1  p13.3  ...  ensembl_havana      14
#
#      peptide_version external_synonym  \
# 0                6.0            GOPP1
# 1                6.0            GOPP1
# 2                6.0            GOPP1
# 3                6.0            GOPP1
# 4                6.0            GOPP1
# ..               ...              ...
# 451              NaN            VPS74
# 452              NaN            VPS74
# 453              NaN            VPS74
# 454              NaN            VPS74
# 455              NaN            VPS74
#
#                                  phenotype_description         source_name  \
# 0              Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census
# 1                               Hepatobiliary Neoplasm  Cancer Gene Census
# 2                                                   ND  Cancer Gene Census
# 3    Ovarian Endometrioid Adenocarcinoma with Squam...  Cancer Gene Census
# 4                               Uterine Carcinosarcoma  Cancer Gene Census
# ..                                                 ...                 ...
# 451                                     skin carcinoma  Cancer Gene Census
# 452                          Small cell lung carcinoma  Cancer Gene Census
# 453                                soft tissue sarcoma  Cancer Gene Census
# 454                       squamous cell lung carcinoma  Cancer Gene Census
# 455                                  thyroid carcinoma  Cancer Gene Census
#
#      p_value MONDO_match                                 MONDO_ClassID  \
# 0        NaN        True  http://purl.obolibrary.org/obo/MONDO_0005461
# 1        NaN        True  http://purl.obolibrary.org/obo/MONDO_0002514
# 2        NaN        True  http://purl.obolibrary.org/obo/MONDO_0010691
# 3        NaN        True  http://purl.obolibrary.org/obo/MONDO_0006336
# 4        NaN        True  http://purl.obolibrary.org/obo/MONDO_0016259
# ..       ...         ...                                           ...
# 451      NaN        True  http://purl.obolibrary.org/obo/MONDO_0002656
# 452      NaN        True  http://purl.obolibrary.org/obo/MONDO_0008433
# 453      NaN        True  http://purl.obolibrary.org/obo/MONDO_0018078
# 454      NaN        True  http://purl.obolibrary.org/obo/MONDO_0005097
# 455      NaN        True  http://purl.obolibrary.org/obo/MONDO_0015075
#
#                                         MONDO_synonims
# 0    ['endometrial endometrioid adenocarcinoma', 'e...
# 1    ['hepatobiliary benign neoplasm', 'hepatobilia...
# 2    ['NDP', 'nd', 'Norrie syndrome', 'pseudoglioma...
# 3    ['ovarian adenoacanthoma', 'ovarian adenosquam...
# 4    ['carcinosarcoma of the uterus', 'malignant mi...
# ..                                                 ...
# 451  ['skin cancer, non-melanoma', 'non-melanoma ca...
# 452  ['SCLC1', 'small cell cancer of the lung', 'po...
# 453  ['malignant soft tissue tumour', 'malignant so...
# 454  ['squamous cell carcinoma of lung', 'squamous ...
# 455  ['thyroid cancer', 'head and neck cancer, thyr...
#
# [456 rows x 24 columns]

# %%
label ='MONDO'
small_ds = ds[['phenotype_description',
               'source_name',
               label+'_match', label+'_ClassID', label+'_synonims', 
               onto_label+'_match', onto_label+'_ClassID', onto_label+'_synonims', ]]

small_ds.to_excel(ds_name+'_'+onto_label+'_'+label+'_match_s.xlsx')
small_ds
# Out:
#                                  phenotype_description         source_name  \
# 0              Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census
# 1                               Hepatobiliary Neoplasm  Cancer Gene Census
# 2                                                   ND  Cancer Gene Census
# 3    Ovarian Endometrioid Adenocarcinoma with Squam...  Cancer Gene Census
# 4                               Uterine Carcinosarcoma  Cancer Gene Census
# ..                                                 ...                 ...
# 451                                     skin carcinoma  Cancer Gene Census
# 452                          Small cell lung carcinoma  Cancer Gene Census
# 453                                soft tissue sarcoma  Cancer Gene Census
# 454                       squamous cell lung carcinoma  Cancer Gene Census
# 455                                  thyroid carcinoma  Cancer Gene Census
#
#      MONDO_match                                 MONDO_ClassID  \
# 0           True  http://purl.obolibrary.org/obo/MONDO_0005461
# 1           True  http://purl.obolibrary.org/obo/MONDO_0002514
# 2           True  http://purl.obolibrary.org/obo/MONDO_0010691
# 3           True  http://purl.obolibrary.org/obo/MONDO_0006336
# 4           True  http://purl.obolibrary.org/obo/MONDO_0016259
# ..           ...                                           ...
# 451         True  http://purl.obolibrary.org/obo/MONDO_0002656
# 452         True  http://purl.obolibrary.org/obo/MONDO_0008433
# 453         True  http://purl.obolibrary.org/obo/MONDO_0018078
# 454         True  http://purl.obolibrary.org/obo/MONDO_0005097
# 455         True  http://purl.obolibrary.org/obo/MONDO_0015075
#
#                                         MONDO_synonims  DOID_match  \
# 0    [endometrial endometrioid adenocarcinoma, endo...        True
# 1    [hepatobiliary benign neoplasm, hepatobiliary ...       False
# 2    [NDP, nd, Norrie syndrome, pseudoglioma, Norri...       False
# 3    [ovarian adenoacanthoma, ovarian adenosquamous...       False
# 4    [malignant mixed müllerian tumour of corpus ut...        True
# ..                                                 ...         ...
# 451  [skin cancer, non-melanoma, non-melanoma cance...        True
# 452  [SCLC1, small cell cancer of the lung, poorly ...       False
# 453  [malignant soft tissue tumour, malignant soft ...       False
# 454  [squamous cell carcinoma of lung, squamous cel...       False
# 455  [thyroid cancer, head and neck cancer, thyroid...       False
#
#                                  DOID_ClassID  \
# 0    http://purl.obolibrary.org/obo/DOID_2870
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4    http://purl.obolibrary.org/obo/DOID_6171
# ..                                        ...
# 451  http://purl.obolibrary.org/obo/DOID_3451
# 452                                       nan
# 453                                       nan
# 454                                       nan
# 455                                       nan
#
#                                          DOID_synonims
# 0    [adenocarcinoma of the Endometrium, endometria...
# 1                                                  nan
# 2                                                  nan
# 3                                                  nan
# 4    [mixed mullerian sarcoma of uterus, uterine ca...
# ..                                                 ...
# 451                [carcinoma of skin, skin carcinoma]
# 452                                                nan
# 453                                                nan
# 454                                                nan
# 455                                                nan
#
# [456 rows x 8 columns]

# %% [markdown]
# ### DOID

# %%
# %%time 
# Choose Ontology 
doid = pd.read_csv('DOID.csv', low_memory=False)
onto_label = 'DOID'
doid = extract_syn_list(doid)

ds = pd.read_csv('emsembl_golph3_dataset.csv', index_col=0)
ds[onto_label+'_match'] = False

ontology_matcher(ds, doid, 'DOID')
# Note: Before running this code, make sure you have a column named 'is_true' in the 'ds' dataframe to store the True values.
#       You may need to initialize this column to False for all rows before the loop.
# Out:
# CPU times: total: 7.45 s
# Wall time: 7.89 s

# %%
cols = ['ensembl_gene_id', 'ensembl_gene_id_version', 'ensembl_peptide_id',
        'ensembl_peptide_id_version', 'description', 'chromosome_name',
        'start_position', 'end_position', 'strand', 'band',
        'external_gene_name', 'external_gene_source',
        'percentage_gene_gc_content', 'gene_biotype', 'source', 'version',
        'peptide_version', 'external_synonym', 'phenotype_description',
        'source_name', 'p_value', onto_label+'_match', onto_label+'_ClassID', onto_label+'_synonims']

ds[cols]#.to_csv('golph3_doid_match.csv')

# %% [markdown]
# # Analyze results

# %%
golph3_doid = pd.read_csv('golph3_doid_match.csv')
golph3_mondo = pd.read_csv('golph3_mondo_match.csv')
golph3_doid
# Out:
#      Unnamed: 0  ensembl_gene_id ensembl_gene_id_version ensembl_peptide_id  \
# 0             0  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 1             1  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 2             2  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 3             3  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 4             4  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# ..          ...              ...                     ...                ...
# 451         451  ENSG00000113384      ENSG00000113384.14                NaN
# 452         452  ENSG00000113384      ENSG00000113384.14                NaN
# 453         453  ENSG00000113384      ENSG00000113384.14                NaN
# 454         454  ENSG00000113384      ENSG00000113384.14                NaN
# 455         455  ENSG00000113384      ENSG00000113384.14                NaN
#
#     ensembl_peptide_id_version  \
# 0            ENSP00000265070.6
# 1            ENSP00000265070.6
# 2            ENSP00000265070.6
# 3            ENSP00000265070.6
# 4            ENSP00000265070.6
# ..                         ...
# 451                        NaN
# 452                        NaN
# 453                        NaN
# 454                        NaN
# 455                        NaN
#
#                                            description  chromosome_name  \
# 0    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 1    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 2    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 3    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 4    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# ..                                                 ...              ...
# 451  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 452  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 453  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 454  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 455  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
#
#      start_position  end_position  strand  ...          source version  \
# 0          32124716      32174319      -1  ...  ensembl_havana      14
# 1          32124716      32174319      -1  ...  ensembl_havana      14
# 2          32124716      32174319      -1  ...  ensembl_havana      14
# 3          32124716      32174319      -1  ...  ensembl_havana      14
# 4          32124716      32174319      -1  ...  ensembl_havana      14
# ..              ...           ...     ...  ...             ...     ...
# 451        32124716      32174319      -1  ...  ensembl_havana      14
# 452        32124716      32174319      -1  ...  ensembl_havana      14
# 453        32124716      32174319      -1  ...  ensembl_havana      14
# 454        32124716      32174319      -1  ...  ensembl_havana      14
# 455        32124716      32174319      -1  ...  ensembl_havana      14
#
#     peptide_version  external_synonym  \
# 0               6.0             GOPP1
# 1               6.0             GOPP1
# 2               6.0             GOPP1
# 3               6.0             GOPP1
# 4               6.0             GOPP1
# ..              ...               ...
# 451             NaN             VPS74
# 452             NaN             VPS74
# 453             NaN             VPS74
# 454             NaN             VPS74
# 455             NaN             VPS74
#
#                                  phenotype_description         source_name  \
# 0              Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census
# 1                               Hepatobiliary Neoplasm  Cancer Gene Census
# 2                                                   ND  Cancer Gene Census
# 3    Ovarian Endometrioid Adenocarcinoma with Squam...  Cancer Gene Census
# 4                               Uterine Carcinosarcoma  Cancer Gene Census
# ..                                                 ...                 ...
# 451                                     skin carcinoma  Cancer Gene Census
# 452                          Small cell lung carcinoma  Cancer Gene Census
# 453                                soft tissue sarcoma  Cancer Gene Census
# 454                       squamous cell lung carcinoma  Cancer Gene Census
# 455                                  thyroid carcinoma  Cancer Gene Census
#
#      p_value  DOID_match                              DOID_ClassID  \
# 0        NaN        True  http://purl.obolibrary.org/obo/DOID_2870
# 1        NaN       False                                       NaN
# 2        NaN       False                                       NaN
# 3        NaN       False                                       NaN
# 4        NaN        True  http://purl.obolibrary.org/obo/DOID_6171
# ..       ...         ...                                       ...
# 451      NaN        True  http://purl.obolibrary.org/obo/DOID_3451
# 452      NaN       False                                       NaN
# 453      NaN       False                                       NaN
# 454      NaN       False                                       NaN
# 455      NaN        True  http://purl.obolibrary.org/obo/DOID_3963
#
#                                          DOID_synonims
# 0    ['endometrioid carcinoma of Endometrium', 'end...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    ['mixed mullerian sarcoma of uterus', 'uterine...
# ..                                                 ...
# 451            ['carcinoma of skin', 'skin carcinoma']
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455  ['head and neck cancer, Thyroid', 'Thyroid car...
#
# [456 rows x 25 columns]

# %%
golph3_doid.query('DOID_match')
# Out:
#      Unnamed: 0  ensembl_gene_id ensembl_gene_id_version ensembl_peptide_id  \
# 0             0  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 4             4  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 5             5  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 6             6  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 7             7  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# ..          ...              ...                     ...                ...
# 448         448  ENSG00000113384      ENSG00000113384.14                NaN
# 449         449  ENSG00000113384      ENSG00000113384.14                NaN
# 450         450  ENSG00000113384      ENSG00000113384.14                NaN
# 451         451  ENSG00000113384      ENSG00000113384.14                NaN
# 455         455  ENSG00000113384      ENSG00000113384.14                NaN
#
#     ensembl_peptide_id_version  \
# 0            ENSP00000265070.6
# 4            ENSP00000265070.6
# 5            ENSP00000265070.6
# 6            ENSP00000265070.6
# 7            ENSP00000265070.6
# ..                         ...
# 448                        NaN
# 449                        NaN
# 450                        NaN
# 451                        NaN
# 455                        NaN
#
#                                            description  chromosome_name  \
# 0    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 4    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 5    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 6    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 7    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# ..                                                 ...              ...
# 448  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 449  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 450  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 451  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 455  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
#
#      start_position  end_position  strand  ...          source version  \
# 0          32124716      32174319      -1  ...  ensembl_havana      14
# 4          32124716      32174319      -1  ...  ensembl_havana      14
# 5          32124716      32174319      -1  ...  ensembl_havana      14
# 6          32124716      32174319      -1  ...  ensembl_havana      14
# 7          32124716      32174319      -1  ...  ensembl_havana      14
# ..              ...           ...     ...  ...             ...     ...
# 448        32124716      32174319      -1  ...  ensembl_havana      14
# 449        32124716      32174319      -1  ...  ensembl_havana      14
# 450        32124716      32174319      -1  ...  ensembl_havana      14
# 451        32124716      32174319      -1  ...  ensembl_havana      14
# 455        32124716      32174319      -1  ...  ensembl_havana      14
#
#     peptide_version  external_synonym  \
# 0               6.0             GOPP1
# 4               6.0             GOPP1
# 5               6.0             GOPP1
# 6               6.0             GOPP1
# 7               6.0             GOPP1
# ..              ...               ...
# 448             NaN             VPS74
# 449             NaN             VPS74
# 450             NaN             VPS74
# 451             NaN             VPS74
# 455             NaN             VPS74
#
#                        phenotype_description         source_name  p_value  \
# 0    Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census      NaN
# 4                     Uterine Carcinosarcoma  Cancer Gene Census      NaN
# 5                     Acute myeloid leukemia  Cancer Gene Census      NaN
# 6                     Anaplastic astrocytoma  Cancer Gene Census      NaN
# 7                        bile duct carcinoma  Cancer Gene Census      NaN
# ..                                       ...                 ...      ...
# 448                  prostate adenocarcinoma  Cancer Gene Census      NaN
# 449                       prostate carcinoma  Cancer Gene Census      NaN
# 450                    rectal adenocarcinoma  Cancer Gene Census      NaN
# 451                           skin carcinoma  Cancer Gene Census      NaN
# 455                        thyroid carcinoma  Cancer Gene Census      NaN
#
#      DOID_match                               DOID_ClassID  \
# 0          True   http://purl.obolibrary.org/obo/DOID_2870
# 4          True   http://purl.obolibrary.org/obo/DOID_6171
# 5          True   http://purl.obolibrary.org/obo/DOID_9119
# 6          True   http://purl.obolibrary.org/obo/DOID_3078
# 7          True   http://purl.obolibrary.org/obo/DOID_4897
# ..          ...                                        ...
# 448        True   http://purl.obolibrary.org/obo/DOID_2526
# 449        True  http://purl.obolibrary.org/obo/DOID_10286
# 450        True   http://purl.obolibrary.org/obo/DOID_1996
# 451        True   http://purl.obolibrary.org/obo/DOID_3451
# 455        True   http://purl.obolibrary.org/obo/DOID_3963
#
#                                          DOID_synonims
# 0    ['endometrioid carcinoma of Endometrium', 'end...
# 4    ['mixed mullerian sarcoma of uterus', 'uterine...
# 5    ['acute myeloid leukaemia', 'acute myelogenous...
# 6    ['grade III astrocytoma', 'grade III Astrocyti...
# 7                       ['nan', 'bile duct carcinoma']
# ..                                                 ...
# 448                 ['nan', 'prostate adenocarcinoma']
# 449  ['carcinoma of prostate', 'cancer of prostate'...
# 450  ['Rectal adenocarcinoma', 'rectum adenocarcino...
# 451            ['carcinoma of skin', 'skin carcinoma']
# 455  ['head and neck cancer, Thyroid', 'Thyroid car...
#
# [312 rows x 25 columns]

# %%
golph3_mondo.query('MONDO_match')

# %%
golph3_mondo.query('MONDO_match == True').query('phenotype_description.str.contains("carcinoma")')
# Out:
#      Unnamed: 0  ensembl_gene_id ensembl_gene_id_version ensembl_peptide_id  \
# 0             0  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 3             3  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 7             7  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 8             8  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# 10           10  ENSG00000113384      ENSG00000113384.14    ENSP00000265070
# ..          ...              ...                     ...                ...
# 450         450  ENSG00000113384      ENSG00000113384.14                NaN
# 451         451  ENSG00000113384      ENSG00000113384.14                NaN
# 452         452  ENSG00000113384      ENSG00000113384.14                NaN
# 454         454  ENSG00000113384      ENSG00000113384.14                NaN
# 455         455  ENSG00000113384      ENSG00000113384.14                NaN
#
#     ensembl_peptide_id_version  \
# 0            ENSP00000265070.6
# 3            ENSP00000265070.6
# 7            ENSP00000265070.6
# 8            ENSP00000265070.6
# 10           ENSP00000265070.6
# ..                         ...
# 450                        NaN
# 451                        NaN
# 452                        NaN
# 454                        NaN
# 455                        NaN
#
#                                            description  chromosome_name  \
# 0    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 3    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 7    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 8    golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 10   golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# ..                                                 ...              ...
# 450  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 451  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 452  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 454  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
# 455  golgi phosphoprotein 3 [Source:HGNC Symbol;Acc...                5
#
#      start_position  end_position  strand  ...          source version  \
# 0          32124716      32174319      -1  ...  ensembl_havana      14
# 3          32124716      32174319      -1  ...  ensembl_havana      14
# 7          32124716      32174319      -1  ...  ensembl_havana      14
# 8          32124716      32174319      -1  ...  ensembl_havana      14
# 10         32124716      32174319      -1  ...  ensembl_havana      14
# ..              ...           ...     ...  ...             ...     ...
# 450        32124716      32174319      -1  ...  ensembl_havana      14
# 451        32124716      32174319      -1  ...  ensembl_havana      14
# 452        32124716      32174319      -1  ...  ensembl_havana      14
# 454        32124716      32174319      -1  ...  ensembl_havana      14
# 455        32124716      32174319      -1  ...  ensembl_havana      14
#
#     peptide_version  external_synonym  \
# 0               6.0             GOPP1
# 3               6.0             GOPP1
# 7               6.0             GOPP1
# 8               6.0             GOPP1
# 10              6.0             GOPP1
# ..              ...               ...
# 450             NaN             VPS74
# 451             NaN             VPS74
# 452             NaN             VPS74
# 454             NaN             VPS74
# 455             NaN             VPS74
#
#                                  phenotype_description         source_name  \
# 0              Endometrial Endometrioid Adenocarcinoma  Cancer Gene Census
# 3    Ovarian Endometrioid Adenocarcinoma with Squam...  Cancer Gene Census
# 7                                  bile duct carcinoma  Cancer Gene Census
# 8                  bladder transitional cell carcinoma  Cancer Gene Census
# 10                                    Breast carcinoma  Cancer Gene Census
# ..                                                 ...                 ...
# 450                              rectal adenocarcinoma  Cancer Gene Census
# 451                                     skin carcinoma  Cancer Gene Census
# 452                          Small cell lung carcinoma  Cancer Gene Census
# 454                       squamous cell lung carcinoma  Cancer Gene Census
# 455                                  thyroid carcinoma  Cancer Gene Census
#
#      p_value  MONDO_match                                 MONDO_ClassID  \
# 0        NaN         True  http://purl.obolibrary.org/obo/MONDO_0005461
# 3        NaN         True  http://purl.obolibrary.org/obo/MONDO_0006336
# 7        NaN         True  http://purl.obolibrary.org/obo/MONDO_0005496
# 8        NaN         True  http://purl.obolibrary.org/obo/MONDO_0005611
# 10       NaN         True  http://purl.obolibrary.org/obo/MONDO_0004989
# ..       ...          ...                                           ...
# 450      NaN         True  http://purl.obolibrary.org/obo/MONDO_0002169
# 451      NaN         True  http://purl.obolibrary.org/obo/MONDO_0002656
# 452      NaN         True  http://purl.obolibrary.org/obo/MONDO_0008433
# 454      NaN         True  http://purl.obolibrary.org/obo/MONDO_0005097
# 455      NaN         True  http://purl.obolibrary.org/obo/MONDO_0015075
#
#                                         MONDO_synonims
# 0    ['endometrial endometrioid adenocarcinoma', 'e...
# 3    ['ovarian adenoacanthoma', 'ovarian adenosquam...
# 7    ['bile duct cancer', 'bile duct cancer (includ...
# 8    ['BLCA', 'urothelial carcinoma of the urinary ...
# 10   ['cancer of breast', 'cancer, breast', 'cancer...
# ..                                                 ...
# 450  ['read', 'rectum adenocarcinoma', 'adenocarcin...
# 451  ['skin cancer, non-melanoma', 'non-melanoma ca...
# 452  ['SCLC1', 'small cell cancer of the lung', 'po...
# 454  ['squamous cell carcinoma of lung', 'squamous ...
# 455  ['thyroid cancer', 'head and neck cancer, thyr...
#
# [300 rows x 25 columns]

# %%
golph3_mondo.query('MONDO_match').groupby('phenotype_description').describe(include=[object])
# Out:
#                                                    ensembl_gene_id         \
#                                                              count unique
# phenotype_description
# Acute myeloid leukemia                                          12      1
# Anaplastic astrocytoma                                          12      1
# Breast carcinoma                                                12      1
# Chronic lymphocytic leukemia                                    12      1
# Clear cell renal carcinoma                                      12      1
# Endometrial Endometrioid Adenocarcinoma                         12      1
# Hepatobiliary Neoplasm                                          12      1
# Hepatocellular Carcinoma                                        12      1
# Lung adenocarcinoma                                             12      1
# Lung carcinoma                                                  12      1
# Melanoma                                                        12      1
# ND                                                              12      1
# Ovarian Endometrioid Adenocarcinoma with Squamo...              12      1
# Small cell lung carcinoma                                       12      1
# Uterine Carcinosarcoma                                          12      1
# bile duct carcinoma                                             12      1
# bladder transitional cell carcinoma                             12      1
# brain glioblastoma                                              12      1
# breast ductal adenocarcinoma                                    12      1
# cecum adenocarcinoma                                            12      1
# cervical squamous cell carcinoma                                12      1
# colon adenocarcinoma                                            12      1
# colorectal adenocarcinoma                                       12      1
# gastric adenocarcinoma                                          12      1
# head and neck squamous cell carcinoma                           12      1
# kidney neoplasm                                                 12      1
# lobular breast carcinoma                                        12      1
# lymphoid neoplasm                                               12      1
# pancreatic carcinoma                                            12      1
# pancreatic ductal adenocarcinoma                                12      1
# pancreatic neuroendocrine tumor                                 12      1
# prostate adenocarcinoma                                         12      1
# prostate carcinoma                                              12      1
# rectal adenocarcinoma                                           12      1
# skin carcinoma                                                  12      1
# soft tissue sarcoma                                             12      1
# squamous cell lung carcinoma                                    12      1
# thyroid carcinoma                                               12      1
#
#                                                                           \
#                                                                 top freq
# phenotype_description
# Acute myeloid leukemia                              ENSG00000113384   12
# Anaplastic astrocytoma                              ENSG00000113384   12
# Breast carcinoma                                    ENSG00000113384   12
# Chronic lymphocytic leukemia                        ENSG00000113384   12
# Clear cell renal carcinoma                          ENSG00000113384   12
# Endometrial Endometrioid Adenocarcinoma             ENSG00000113384   12
# Hepatobiliary Neoplasm                              ENSG00000113384   12
# Hepatocellular Carcinoma                            ENSG00000113384   12
# Lung adenocarcinoma                                 ENSG00000113384   12
# Lung carcinoma                                      ENSG00000113384   12
# Melanoma                                            ENSG00000113384   12
# ND                                                  ENSG00000113384   12
# Ovarian Endometrioid Adenocarcinoma with Squamo...  ENSG00000113384   12
# Small cell lung carcinoma                           ENSG00000113384   12
# Uterine Carcinosarcoma                              ENSG00000113384   12
# bile duct carcinoma                                 ENSG00000113384   12
# bladder transitional cell carcinoma                 ENSG00000113384   12
# brain glioblastoma                                  ENSG00000113384   12
# breast ductal adenocarcinoma                        ENSG00000113384   12
# cecum adenocarcinoma                                ENSG00000113384   12
# cervical squamous cell carcinoma                    ENSG00000113384   12
# colon adenocarcinoma                                ENSG00000113384   12
# colorectal adenocarcinoma                           ENSG00000113384   12
# gastric adenocarcinoma                              ENSG00000113384   12
# head and neck squamous cell carcinoma               ENSG00000113384   12
# kidney neoplasm                                     ENSG00000113384   12
# lobular breast carcinoma                            ENSG00000113384   12
# lymphoid neoplasm                                   ENSG00000113384   12
# pancreatic carcinoma                                ENSG00000113384   12
# pancreatic ductal adenocarcinoma                    ENSG00000113384   12
# pancreatic neuroendocrine tumor                     ENSG00000113384   12
# prostate adenocarcinoma                             ENSG00000113384   12
# prostate carcinoma                                  ENSG00000113384   12
# rectal adenocarcinoma                               ENSG00000113384   12
# skin carcinoma                                      ENSG00000113384   12
# soft tissue sarcoma                                 ENSG00000113384   12
# squamous cell lung carcinoma                        ENSG00000113384   12
# thyroid carcinoma                                   ENSG00000113384   12
#
#                                                    ensembl_gene_id_version  \
#                                                                      count
# phenotype_description
# Acute myeloid leukemia                                                  12
# Anaplastic astrocytoma                                                  12
# Breast carcinoma                                                        12
# Chronic lymphocytic leukemia                                            12
# Clear cell renal carcinoma                                              12
# Endometrial Endometrioid Adenocarcinoma                                 12
# Hepatobiliary Neoplasm                                                  12
# Hepatocellular Carcinoma                                                12
# Lung adenocarcinoma                                                     12
# Lung carcinoma                                                          12
# Melanoma                                                                12
# ND                                                                      12
# Ovarian Endometrioid Adenocarcinoma with Squamo...                      12
# Small cell lung carcinoma                                               12
# Uterine Carcinosarcoma                                                  12
# bile duct carcinoma                                                     12
# bladder transitional cell carcinoma                                     12
# brain glioblastoma                                                      12
# breast ductal adenocarcinoma                                            12
# cecum adenocarcinoma                                                    12
# cervical squamous cell carcinoma                                        12
# colon adenocarcinoma                                                    12
# colorectal adenocarcinoma                                               12
# gastric adenocarcinoma                                                  12
# head and neck squamous cell carcinoma                                   12
# kidney neoplasm                                                         12
# lobular breast carcinoma                                                12
# lymphoid neoplasm                                                       12
# pancreatic carcinoma                                                    12
# pancreatic ductal adenocarcinoma                                        12
# pancreatic neuroendocrine tumor                                         12
# prostate adenocarcinoma                                                 12
# prostate carcinoma                                                      12
# rectal adenocarcinoma                                                   12
# skin carcinoma                                                          12
# soft tissue sarcoma                                                     12
# squamous cell lung carcinoma                                            12
# thyroid carcinoma                                                       12
#
#                                                                                \
#                                                    unique                 top
# phenotype_description
# Acute myeloid leukemia                                  1  ENSG00000113384.14
# Anaplastic astrocytoma                                  1  ENSG00000113384.14
# Breast carcinoma                                        1  ENSG00000113384.14
# Chronic lymphocytic leukemia                            1  ENSG00000113384.14
# Clear cell renal carcinoma                              1  ENSG00000113384.14
# Endometrial Endometrioid Adenocarcinoma                 1  ENSG00000113384.14
# Hepatobiliary Neoplasm                                  1  ENSG00000113384.14
# Hepatocellular Carcinoma                                1  ENSG00000113384.14
# Lung adenocarcinoma                                     1  ENSG00000113384.14
# Lung carcinoma                                          1  ENSG00000113384.14
# Melanoma                                                1  ENSG00000113384.14
# ND                                                      1  ENSG00000113384.14
# Ovarian Endometrioid Adenocarcinoma with Squamo...      1  ENSG00000113384.14
# Small cell lung carcinoma                               1  ENSG00000113384.14
# Uterine Carcinosarcoma                                  1  ENSG00000113384.14
# bile duct carcinoma                                     1  ENSG00000113384.14
# bladder transitional cell carcinoma                     1  ENSG00000113384.14
# brain glioblastoma                                      1  ENSG00000113384.14
# breast ductal adenocarcinoma                            1  ENSG00000113384.14
# cecum adenocarcinoma                                    1  ENSG00000113384.14
# cervical squamous cell carcinoma                        1  ENSG00000113384.14
# colon adenocarcinoma                                    1  ENSG00000113384.14
# colorectal adenocarcinoma                               1  ENSG00000113384.14
# gastric adenocarcinoma                                  1  ENSG00000113384.14
# head and neck squamous cell carcinoma                   1  ENSG00000113384.14
# kidney neoplasm                                         1  ENSG00000113384.14
# lobular breast carcinoma                                1  ENSG00000113384.14
# lymphoid neoplasm                                       1  ENSG00000113384.14
# pancreatic carcinoma                                    1  ENSG00000113384.14
# pancreatic ductal adenocarcinoma                        1  ENSG00000113384.14
# pancreatic neuroendocrine tumor                         1  ENSG00000113384.14
# prostate adenocarcinoma                                 1  ENSG00000113384.14
# prostate carcinoma                                      1  ENSG00000113384.14
# rectal adenocarcinoma                                   1  ENSG00000113384.14
# skin carcinoma                                          1  ENSG00000113384.14
# soft tissue sarcoma                                     1  ENSG00000113384.14
# squamous cell lung carcinoma                            1  ENSG00000113384.14
# thyroid carcinoma                                       1  ENSG00000113384.14
#
#                                                         ensembl_peptide_id  \
#                                                    freq              count
# phenotype_description
# Acute myeloid leukemia                               12                  8
# Anaplastic astrocytoma                               12                  8
# Breast carcinoma                                     12                  8
# Chronic lymphocytic leukemia                         12                  8
# Clear cell renal carcinoma                           12                  8
# Endometrial Endometrioid Adenocarcinoma              12                  8
# Hepatobiliary Neoplasm                               12                  8
# Hepatocellular Carcinoma                             12                  8
# Lung adenocarcinoma                                  12                  8
# Lung carcinoma                                       12                  8
# Melanoma                                             12                  8
# ND                                                   12                  8
# Ovarian Endometrioid Adenocarcinoma with Squamo...   12                  8
# Small cell lung carcinoma                            12                  8
# Uterine Carcinosarcoma                               12                  8
# bile duct carcinoma                                  12                  8
# bladder transitional cell carcinoma                  12                  8
# brain glioblastoma                                   12                  8
# breast ductal adenocarcinoma                         12                  8
# cecum adenocarcinoma                                 12                  8
# cervical squamous cell carcinoma                     12                  8
# colon adenocarcinoma                                 12                  8
# colorectal adenocarcinoma                            12                  8
# gastric adenocarcinoma                               12                  8
# head and neck squamous cell carcinoma                12                  8
# kidney neoplasm                                      12                  8
# lobular breast carcinoma                             12                  8
# lymphoid neoplasm                                    12                  8
# pancreatic carcinoma                                 12                  8
# pancreatic ductal adenocarcinoma                     12                  8
# pancreatic neuroendocrine tumor                      12                  8
# prostate adenocarcinoma                              12                  8
# prostate carcinoma                                   12                  8
# rectal adenocarcinoma                                12                  8
# skin carcinoma                                       12                  8
# soft tissue sarcoma                                  12                  8
# squamous cell lung carcinoma                         12                  8
# thyroid carcinoma                                    12                  8
#
#                                                            ...  \
#                                                    unique  ...
# phenotype_description                                      ...
# Acute myeloid leukemia                                  2  ...
# Anaplastic astrocytoma                                  2  ...
# Breast carcinoma                                        2  ...
# Chronic lymphocytic leukemia                            2  ...
# Clear cell renal carcinoma                              2  ...
# Endometrial Endometrioid Adenocarcinoma                 2  ...
# Hepatobiliary Neoplasm                                  2  ...
# Hepatocellular Carcinoma                                2  ...
# Lung adenocarcinoma                                     2  ...
# Lung carcinoma                                          2  ...
# Melanoma                                                2  ...
# ND                                                      2  ...
# Ovarian Endometrioid Adenocarcinoma with Squamo...      2  ...
# Small cell lung carcinoma                               2  ...
# Uterine Carcinosarcoma                                  2  ...
# bile duct carcinoma                                     2  ...
# bladder transitional cell carcinoma                     2  ...
# brain glioblastoma                                      2  ...
# breast ductal adenocarcinoma                            2  ...
# cecum adenocarcinoma                                    2  ...
# cervical squamous cell carcinoma                        2  ...
# colon adenocarcinoma                                    2  ...
# colorectal adenocarcinoma                               2  ...
# gastric adenocarcinoma                                  2  ...
# head and neck squamous cell carcinoma                   2  ...
# kidney neoplasm                                         2  ...
# lobular breast carcinoma                                2  ...
# lymphoid neoplasm                                       2  ...
# pancreatic carcinoma                                    2  ...
# pancreatic ductal adenocarcinoma                        2  ...
# pancreatic neuroendocrine tumor                         2  ...
# prostate adenocarcinoma                                 2  ...
# prostate carcinoma                                      2  ...
# rectal adenocarcinoma                                   2  ...
# skin carcinoma                                          2  ...
# soft tissue sarcoma                                     2  ...
# squamous cell lung carcinoma                            2  ...
# thyroid carcinoma                                       2  ...
#
#                                                            source_name       \
#                                                                    top freq
# phenotype_description
# Acute myeloid leukemia                              Cancer Gene Census   12
# Anaplastic astrocytoma                              Cancer Gene Census   12
# Breast carcinoma                                    Cancer Gene Census   12
# Chronic lymphocytic leukemia                        Cancer Gene Census   12
# Clear cell renal carcinoma                          Cancer Gene Census   12
# Endometrial Endometrioid Adenocarcinoma             Cancer Gene Census   12
# Hepatobiliary Neoplasm                              Cancer Gene Census   12
# Hepatocellular Carcinoma                            Cancer Gene Census   12
# Lung adenocarcinoma                                 Cancer Gene Census   12
# Lung carcinoma                                      Cancer Gene Census   12
# Melanoma                                            Cancer Gene Census   12
# ND                                                  Cancer Gene Census   12
# Ovarian Endometrioid Adenocarcinoma with Squamo...  Cancer Gene Census   12
# Small cell lung carcinoma                           Cancer Gene Census   12
# Uterine Carcinosarcoma                              Cancer Gene Census   12
# bile duct carcinoma                                 Cancer Gene Census   12
# bladder transitional cell carcinoma                 Cancer Gene Census   12
# brain glioblastoma                                  Cancer Gene Census   12
# breast ductal adenocarcinoma                        Cancer Gene Census   12
# cecum adenocarcinoma                                Cancer Gene Census   12
# cervical squamous cell carcinoma                    Cancer Gene Census   12
# colon adenocarcinoma                                Cancer Gene Census   12
# colorectal adenocarcinoma                           Cancer Gene Census   12
# gastric adenocarcinoma                              Cancer Gene Census   12
# head and neck squamous cell carcinoma               Cancer Gene Census   12
# kidney neoplasm                                     Cancer Gene Census   12
# lobular breast carcinoma                            Cancer Gene Census   12
# lymphoid neoplasm                                   Cancer Gene Census   12
# pancreatic carcinoma                                Cancer Gene Census   12
# pancreatic ductal adenocarcinoma                    Cancer Gene Census   12
# pancreatic neuroendocrine tumor                     Cancer Gene Census   12
# prostate adenocarcinoma                             Cancer Gene Census   12
# prostate carcinoma                                  Cancer Gene Census   12
# rectal adenocarcinoma                               Cancer Gene Census   12
# skin carcinoma                                      Cancer Gene Census   12
# soft tissue sarcoma                                 Cancer Gene Census   12
# squamous cell lung carcinoma                        Cancer Gene Census   12
# thyroid carcinoma                                   Cancer Gene Census   12
#
#                                                    MONDO_ClassID         \
#                                                            count unique
# phenotype_description
# Acute myeloid leukemia                                        12      1
# Anaplastic astrocytoma                                        12      1
# Breast carcinoma                                              12      1
# Chronic lymphocytic leukemia                                  12      1
# Clear cell renal carcinoma                                    12      1
# Endometrial Endometrioid Adenocarcinoma                       12      1
# Hepatobiliary Neoplasm                                        12      1
# Hepatocellular Carcinoma                                      12      1
# Lung adenocarcinoma                                           12      1
# Lung carcinoma                                                12      1
# Melanoma                                                      12      1
# ND                                                            12      1
# Ovarian Endometrioid Adenocarcinoma with Squamo...            12      1
# Small cell lung carcinoma                                     12      1
# Uterine Carcinosarcoma                                        12      1
# bile duct carcinoma                                           12      1
# bladder transitional cell carcinoma                           12      1
# brain glioblastoma                                            12      1
# breast ductal adenocarcinoma                                  12      1
# cecum adenocarcinoma                                          12      1
# cervical squamous cell carcinoma                              12      1
# colon adenocarcinoma                                          12      1
# colorectal adenocarcinoma                                     12      1
# gastric adenocarcinoma                                        12      1
# head and neck squamous cell carcinoma                         12      1
# kidney neoplasm                                               12      1
# lobular breast carcinoma                                      12      1
# lymphoid neoplasm                                             12      1
# pancreatic carcinoma                                          12      1
# pancreatic ductal adenocarcinoma                              12      1
# pancreatic neuroendocrine tumor                               12      1
# prostate adenocarcinoma                                       12      1
# prostate carcinoma                                            12      1
# rectal adenocarcinoma                                         12      1
# skin carcinoma                                                12      1
# soft tissue sarcoma                                           12      1
# squamous cell lung carcinoma                                  12      1
# thyroid carcinoma                                             12      1
#
#                                                                                                   \
#                                                                                              top
# phenotype_description
# Acute myeloid leukemia                              http://purl.obolibrary.org/obo/MONDO_0018874
# Anaplastic astrocytoma                              http://purl.obolibrary.org/obo/MONDO_0016684
# Breast carcinoma                                    http://purl.obolibrary.org/obo/MONDO_0004989
# Chronic lymphocytic leukemia                        http://purl.obolibrary.org/obo/MONDO_0004948
# Clear cell renal carcinoma                          http://purl.obolibrary.org/obo/MONDO_0005005
# Endometrial Endometrioid Adenocarcinoma             http://purl.obolibrary.org/obo/MONDO_0005461
# Hepatobiliary Neoplasm                              http://purl.obolibrary.org/obo/MONDO_0002514
# Hepatocellular Carcinoma                            http://purl.obolibrary.org/obo/MONDO_0007256
# Lung adenocarcinoma                                 http://purl.obolibrary.org/obo/MONDO_0005061
# Lung carcinoma                                      http://purl.obolibrary.org/obo/MONDO_0005138
# Melanoma                                            http://purl.obolibrary.org/obo/MONDO_0005105
# ND                                                  http://purl.obolibrary.org/obo/MONDO_0010691
# Ovarian Endometrioid Adenocarcinoma with Squamo...  http://purl.obolibrary.org/obo/MONDO_0006336
# Small cell lung carcinoma                           http://purl.obolibrary.org/obo/MONDO_0008433
# Uterine Carcinosarcoma                              http://purl.obolibrary.org/obo/MONDO_0016259
# bile duct carcinoma                                 http://purl.obolibrary.org/obo/MONDO_0005496
# bladder transitional cell carcinoma                 http://purl.obolibrary.org/obo/MONDO_0005611
# brain glioblastoma                                  http://purl.obolibrary.org/obo/MONDO_0002501
# breast ductal adenocarcinoma                        http://purl.obolibrary.org/obo/MONDO_0005590
# cecum adenocarcinoma                                http://purl.obolibrary.org/obo/MONDO_0006028
# cervical squamous cell carcinoma                    http://purl.obolibrary.org/obo/MONDO_0006143
# colon adenocarcinoma                                http://purl.obolibrary.org/obo/MONDO_0002271
# colorectal adenocarcinoma                           http://purl.obolibrary.org/obo/MONDO_0005008
# gastric adenocarcinoma                              http://purl.obolibrary.org/obo/MONDO_0005036
# head and neck squamous cell carcinoma               http://purl.obolibrary.org/obo/MONDO_0010150
# kidney neoplasm                                     http://purl.obolibrary.org/obo/MONDO_0021163
# lobular breast carcinoma                            http://purl.obolibrary.org/obo/MONDO_0000552
# lymphoid neoplasm                                   http://purl.obolibrary.org/obo/MONDO_0005157
# pancreatic carcinoma                                http://purl.obolibrary.org/obo/MONDO_0005192
# pancreatic ductal adenocarcinoma                    http://purl.obolibrary.org/obo/MONDO_0005184
# pancreatic neuroendocrine tumor                     http://purl.obolibrary.org/obo/MONDO_0019954
# prostate adenocarcinoma                             http://purl.obolibrary.org/obo/MONDO_0005082
# prostate carcinoma                                  http://purl.obolibrary.org/obo/MONDO_0005159
# rectal adenocarcinoma                               http://purl.obolibrary.org/obo/MONDO_0002169
# skin carcinoma                                      http://purl.obolibrary.org/obo/MONDO_0002656
# soft tissue sarcoma                                 http://purl.obolibrary.org/obo/MONDO_0018078
# squamous cell lung carcinoma                        http://purl.obolibrary.org/obo/MONDO_0005097
# thyroid carcinoma                                   http://purl.obolibrary.org/obo/MONDO_0015075
#
#                                                         MONDO_synonims         \
#                                                    freq          count unique
# phenotype_description
# Acute myeloid leukemia                               12             12      1
# Anaplastic astrocytoma                               12             12      1
# Breast carcinoma                                     12             12      1
# Chronic lymphocytic leukemia                         12             12      1
# Clear cell renal carcinoma                           12             12      1
# Endometrial Endometrioid Adenocarcinoma              12             12      1
# Hepatobiliary Neoplasm                               12             12      1
# Hepatocellular Carcinoma                             12             12      1
# Lung adenocarcinoma                                  12             12      1
# Lung carcinoma                                       12             12      1
# Melanoma                                             12             12      1
# ND                                                   12             12      1
# Ovarian Endometrioid Adenocarcinoma with Squamo...   12             12      1
# Small cell lung carcinoma                            12             12      1
# Uterine Carcinosarcoma                               12             12      1
# bile duct carcinoma                                  12             12      1
# bladder transitional cell carcinoma                  12             12      1
# brain glioblastoma                                   12             12      1
# breast ductal adenocarcinoma                         12             12      1
# cecum adenocarcinoma                                 12             12      1
# cervical squamous cell carcinoma                     12             12      1
# colon adenocarcinoma                                 12             12      1
# colorectal adenocarcinoma                            12             12      1
# gastric adenocarcinoma                               12             12      1
# head and neck squamous cell carcinoma                12             12      1
# kidney neoplasm                                      12             12      1
# lobular breast carcinoma                             12             12      1
# lymphoid neoplasm                                    12             12      1
# pancreatic carcinoma                                 12             12      1
# pancreatic ductal adenocarcinoma                     12             12      1
# pancreatic neuroendocrine tumor                      12             12      1
# prostate adenocarcinoma                              12             12      1
# prostate carcinoma                                   12             12      1
# rectal adenocarcinoma                                12             12      1
# skin carcinoma                                       12             12      1
# soft tissue sarcoma                                  12             12      1
# squamous cell lung carcinoma                         12             12      1
# thyroid carcinoma                                    12             12      1
#
#                                                                                                        \
#                                                                                                   top
# phenotype_description
# Acute myeloid leukemia                              ['leukemia, acute myeloid', 'acute non lymphob...
# Anaplastic astrocytoma                              ['grade III astrocytic tumor', 'anaplastic ast...
# Breast carcinoma                                    ['cancer of breast', 'cancer, breast', 'cancer...
# Chronic lymphocytic leukemia                        ['small lymphocytic lymphoma', 'leukemia, chro...
# Clear cell renal carcinoma                          ['hypernephroma', 'clear-cell metastatic renal...
# Endometrial Endometrioid Adenocarcinoma             ['endometrial endometrioid adenocarcinoma', 'e...
# Hepatobiliary Neoplasm                              ['hepatobiliary benign neoplasm', 'hepatobilia...
# Hepatocellular Carcinoma                            ['adult primary hepatocellular carcinoma', 'ad...
# Lung adenocarcinoma                                 ['non-small cell lung adenocarcinoma', 'adenoc...
# Lung carcinoma                                      ['lung cancer, NOS', 'lung cancer', 'cancer of...
# Melanoma                                            ['melanoma, malignant', 'melanoma', 'malignant...
# ND                                                  ['NDP', 'nd', 'Norrie syndrome', 'pseudoglioma...
# Ovarian Endometrioid Adenocarcinoma with Squamo...  ['ovarian adenoacanthoma', 'ovarian adenosquam...
# Small cell lung carcinoma                           ['SCLC1', 'small cell cancer of the lung', 'po...
# Uterine Carcinosarcoma                              ['carcinosarcoma of the uterus', 'malignant mi...
# bile duct carcinoma                                 ['bile duct cancer', 'bile duct cancer (includ...
# bladder transitional cell carcinoma                 ['BLCA', 'urothelial carcinoma of the urinary ...
# brain glioblastoma                                  ['glioblastoma multiforme of the brain', 'brai...
# breast ductal adenocarcinoma                        ['ductal adenocarcinoma', 'duct adenocarcinoma...
# cecum adenocarcinoma                                ['adenocarcinoma of the cecum', 'cecal adenoca...
# cervical squamous cell carcinoma                    ['CESC', 'squamous cell carcinoma of the uteri...
# colon adenocarcinoma                                ['COAD', 'adenocarcinoma - colon', 'adenocarci...
# colorectal adenocarcinoma                           ['large bowel adenocarcinoma', 'adenocarcinoma...
# gastric adenocarcinoma                              ['STAD', 'adenocarcinoma of stomach', 'gastric...
# head and neck squamous cell carcinoma               ['carcinoma of the head and neck', 'squamous c...
# kidney neoplasm                                     ['neoplasm of the kidney', 'kidney neoplasm', ...
# lobular breast carcinoma                            ['lobular adenocarcinoma', 'lobular carcinoma ...
# lymphoid neoplasm                                   ['lymphoid and plasma cell tumour', 'lymphocyt...
# pancreatic carcinoma                                ['pancreatic carcinoma, familial', 'exocrine c...
# pancreatic ductal adenocarcinoma                    ['ductal adenocarcinoma of pancreas', 'pancrea...
# pancreatic neuroendocrine tumor                     ['neuroendocrine tumour of pancreas', 'pancrea...
# prostate adenocarcinoma                             ['prad', 'adenocarcinoma of the prostate', 'ad...
# prostate carcinoma                                  ['cancer of prostate', 'cancer of the prostate...
# rectal adenocarcinoma                               ['read', 'rectum adenocarcinoma', 'adenocarcin...
# skin carcinoma                                      ['skin cancer, non-melanoma', 'non-melanoma ca...
# soft tissue sarcoma                                 ['malignant soft tissue tumour', 'malignant so...
# squamous cell lung carcinoma                        ['squamous cell carcinoma of lung', 'squamous ...
# thyroid carcinoma                                   ['thyroid cancer', 'head and neck cancer, thyr...
#
#
#                                                    freq
# phenotype_description
# Acute myeloid leukemia                               12
# Anaplastic astrocytoma                               12
# Breast carcinoma                                     12
# Chronic lymphocytic leukemia                         12
# Clear cell renal carcinoma                           12
# Endometrial Endometrioid Adenocarcinoma              12
# Hepatobiliary Neoplasm                               12
# Hepatocellular Carcinoma                             12
# Lung adenocarcinoma                                  12
# Lung carcinoma                                       12
# Melanoma                                             12
# ND                                                   12
# Ovarian Endometrioid Adenocarcinoma with Squamo...   12
# Small cell lung carcinoma                            12
# Uterine Carcinosarcoma                               12
# bile duct carcinoma                                  12
# bladder transitional cell carcinoma                  12
# brain glioblastoma                                   12
# breast ductal adenocarcinoma                         12
# cecum adenocarcinoma                                 12
# cervical squamous cell carcinoma                     12
# colon adenocarcinoma                                 12
# colorectal adenocarcinoma                            12
# gastric adenocarcinoma                               12
# head and neck squamous cell carcinoma                12
# kidney neoplasm                                      12
# lobular breast carcinoma                             12
# lymphoid neoplasm                                    12
# pancreatic carcinoma                                 12
# pancreatic ductal adenocarcinoma                     12
# pancreatic neuroendocrine tumor                      12
# prostate adenocarcinoma                              12
# prostate carcinoma                                   12
# rectal adenocarcinoma                                12
# skin carcinoma                                       12
# soft tissue sarcoma                                  12
# squamous cell lung carcinoma                         12
# thyroid carcinoma                                    12
#
# [38 rows x 56 columns]

# %% [markdown]
# # Results
# The semantic enrichment process yielded improvements in data interoperability and discoverability:
#
# ### Matched Terms
# Through the ontology matching process, a considerable number of phenotypic terms were successfully matched to disease ontology terms. Specifically, out of the total phenotypic terms present in the dataset, **68%** were matched with DOID terms and **100%** with MONDO terms.
#
# ### Ontology Cross-Referencing
# The inclusion of IRI class IDs allowed for enhanced cross-referencing between phenotypic data and disease ontology terms. This cross-referencing facilitates seamless integration with other datasets and ontologies, fostering improved data analytics and hypothesis generation.
#
# ## Discussion
# The successful integration of DOID and MONDO ontologies into the GOLPH3 dataset enhances its usability in bioinformatics research. The semantically enriched dataset now allows researchers to more easily query and draw connections between the GOLPH3 gene and various diseases. This is critical for uncovering new disease pathways and understanding GOLPH3's role in different pathological conditions.
#
# Additionally, the use of IRI class IDs ensures that the dataset is amenable to automated data retrieval systems and interoperable with other ontological resources. This alignment with FAIR principles further underscores the dataset's utility for the broader scientific community.
#
# ## Conclusion
# The semantic enrichment of the GOLPH3 gene dataset through ontology matching has significantly advanced its FAIR compliance and research applicability. Future work will focus on expanding the range of ontologies used and refining the matching algorithms to improve the precision and recall of the ontology matcher.

# %% [markdown]
# # Extra
#
# ## load OWL

# %% [markdown]
# ## Load OBO

# %%
# %%time
# https://notebook.community/dhimmel/obo/examples/go-obonet
import sys, time
import obonet
import networkx as nx

#3. Download and load the Mondo ontology file:
mondo_url = 'http://purl.obolibrary.org/obo/mondo.obo'
graph = obonet.read_obo(mondo_url)
graph_nodes = graph.nodes()
print('Number of nodes:',len(graph))
time.sleep(0.5)
print("Memory Usage:", sys.getsizeof(graph), "bytes")
print("Memory Usage:", sys.getsizeof(graph_nodes), "bytes")
list(graph_nodes)[:5]
# Out:
# Number of nodes: 24399
# CPU times: total: 7.14 s
# Wall time: 11.3 s

# %%
#graph.nodes['DOID:9744']
graph.nodes['MONDO:0000023']
# Out:
# {'name': 'type 1 diabetes mellitus',
#  'def': '"A diabetes mellitus that is characterized by destruction of pancreatic beta cells resulting in absent or extremely low insulin production." [url:http\\://en.wikipedia.org/wiki/Diabetes, url:http\\://en.wikipedia.org/wiki/Diabetes_mellitus_type_1]',
#  'comment': 'Xref MGI.\\nOMIM mapping confirmed by DO. [SN].',
#  'subset': ['DO_rare_slim', 'NCIthesaurus'],
#  'synonym': ['"IDDM" EXACT []',
#   '"insulin-dependent diabetes mellitus" EXACT []',
#   '"type I diabetes mellitus" EXACT []'],
#  'xref': ['GARD:10268',
#   'ICD10CM:E10',
#   'KEGG:04940',
#   'MESH:D003922',
#   'NCI:C2986',
#   'OMIM:222100',
#   'SNOMEDCT_US_2023_03_01:46635009',
#   'UMLS_CUI:C0011854'],
#  'is_a': ['DOID:0060005', 'DOID:9351']}

# %%
#You now have the Mondo ontology loaded in Python as a directed graph. You can perform various operations on the graph, such as accessing nodes and edges, traversing the ontology hierarchy, and querying specific terms.

#For example, you can access information about a specific term using its ID:
term_id = 'MONDO:0005737'  # Replace with your desired term ID
term_data = graph.nodes[term_id]
print(term_data)
#You can also explore the relationships between terms by accessing the graph edges:

term_children = list(graph.successors(term_id))
print('\n'+term_id+' Childerns:',term_children)
# Out:
# {'name': 'Ebola hemorrhagic fever', 'def': '"A viral hemorrhagic fever that is caused by the Ebola virus, which is transmitted by contact with infected animals or humans; it is characterized by high fever, unexplained bleeding, and a high mortality rate." [NCIT:P378]', 'subset': ['gard_rare', 'nord_rare', 'ordo_disease', 'orphanet_rare', 'rare'], 'synonym': ['"Ebola" EXACT [NCIT:C36171]', '"Ebola fever" EXACT [Orphanet:319218]', '"Ebola virus disease" EXACT [DOID:4325, Orphanet:319218]', '"Ebolavirus caused disease or disorder" EXACT [MONDO:patterns/specific_infectious_disease_by_agent]', '"Ebolavirus disease or disorder" EXACT []', '"Ebolavirus infectious disease" EXACT []', '"EHF" EXACT ABBREVIATION [Orphanet:319218]'], 'xref': ['DOID:4325', 'EFO:0007243', 'GARD:2035', 'MedDRA:10014071', 'MESH:D019142', 'NCIT:C36171', 'Orphanet:319218', 'SCTID:37109004', 'UMLS:C0282687'], 'is_a': ['MONDO:0005762', 'MONDO:0018087'], 'relationship': ['disease_has_feature MONDO:0001517', 'disease_has_feature MONDO:0003799'], 'property_value': ['closeMatch http://identifiers.org/meddra/10014071', 'exactMatch DOID:4325', 'exactMatch http://identifiers.org/mesh/D019142', 'exactMatch http://identifiers.org/snomedct/37109004', 'exactMatch http://linkedlifedata.com/resource/umls/id/C0282687', 'exactMatch NCIT:C36171', 'exactMatch Orphanet:319218']}
#
# MONDO:0005737 Childerns: ['MONDO:0005762', 'MONDO:0018087', 'MONDO:0001517', 'MONDO:0003799']

# %%
# Check if the ontology is a DAG
nx.is_directed_acyclic_graph(graph)
# Out:
# False

# %% [markdown]
# A DAG (Directed Acyclic Graph) is a type of graph where the edges have a defined direction, and there are no cycles or loops. In other words, it is a directed graph that does not contain any directed cycles.
#
# In a DAG, each vertex or node represents a concept, and the directed edges represent the relationships between those concepts. The direction of the edges indicates the direction of the relationship, and the absence of cycles ensures that there is no circular or contradictory relationship.
#
# DAGs are commonly used to represent various types of hierarchical structures or relationships, such as family trees, dependencies between tasks in project management, or the hierarchical structure of categories in a classification system.
#
# In the context of ontologies, a DAG is often used to represent the hierarchical relationships between terms or concepts. Each term in the ontology is represented as a node, and the edges represent the parent-child relationships between the terms. For example, in a disease ontology, a term representing a specific disease might have multiple sub-disease terms that represent more specific types or subtypes of that disease.

# %% [markdown]
# ### Lookup node properties

# %%
# Retreive properties of phagocytosis
term = graph.nodes['MONDO:0006909']
print('term:',term)

# Retreive properties of pilus shaft
def get_parent(term):
    parent = term['is_a'][0]
    return graph.nodes[parent]

term2 = get_parent(term)
print('\nparent:',term2)
#get_parent(term2)
# Out:
# term: {'name': 'pituitary dwarfism', 'def': '"Proportionately decreased bodily growth due to failure of the pituitary gland to produce an adequate supply of growth hormone." [NCIT:P378]', 'xref': ['EFO:1001109', 'ICD9:253.3', 'MedDRA:10035083', 'MESH:D004393', 'SCTID:367460001', 'UMLS:C0013338'], 'is_a': ['MONDO:0005495'], 'property_value': ['closeMatch http://identifiers.org/meddra/10035083', 'exactMatch http://identifiers.org/mesh/D004393', 'exactMatch http://identifiers.org/snomedct/367460001', 'exactMatch http://linkedlifedata.com/resource/umls/id/C0013338']}
#
# parent: {'name': 'adrenal gland disorder', 'def': '"A disease involving the adrenal gland." [https://orcid.org/0000-0002-6601-2165]', 'synonym': ['"adrenal gland disease" EXACT [MONDO:patterns/location, NCIT:C26690]', '"adrenal gland disease or disorder" EXACT [MONDO:design_pattern, MONDO:patterns/location]', '"adrenal gland diseases" EXACT [NCIT:C26690]', '"adrenal gland disorder" EXACT [NCIT:C26690]', '"adrenal gland disorders" EXACT [NCIT:C26690]', '"disease of adrenal gland" EXACT [MONDO:patterns/location_top]', '"disease or disorder of adrenal gland" EXACT []', '"disorder of adrenal gland" EXACT [MONDO:patterns/location_top]'], 'xref': ['DOID:9553', 'EFO:0005539', 'ICD9:255', 'ICD9:255.8', 'ICD9:255.9', 'MESH:D000307', 'NCIT:C26690', 'SCTID:30171000'], 'is_a': ['MONDO:0005151'], 'property_value': ['exactMatch DOID:9553', 'exactMatch http://identifiers.org/mesh/D000307', 'exactMatch http://identifiers.org/snomedct/30171000', 'exactMatch NCIT:C26690']}

# %% [markdown]
# ### Create name mappings

# %%
id_to_name = {id_: data.get('name') for id_, data in graph.nodes(data=True)}
name_to_id = {data['name']: id_ for id_, data in graph.nodes(data=True) if 'name' in data}

# Get the name for GO:0042552
id_to_name['GO:0042552']

# Get the id for myelination
name_to_id['myelination']

# %% [markdown]
# ### Find parent or child relationships

# %%
# Find edges to parent terms
#node = name_to_id['pilus part']
node = name_to_id['myelination']

for child, parent, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟶ {key} ⟶ {id_to_name[parent]}')

# %% [markdown]
# ### Find edges to children terms

# %%
#node = name_to_id['pilus part']
node = name_to_id['myelination']
for parent, child, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵ {key} ⟵ {id_to_name[parent]}')

# %% [markdown]
# ### Find all superterms of myelination

# %%
sorted(id_to_name[superterm] for superterm in nx.descendants(graph, 'GO:0042552'))

# %% [markdown]
# ### Find all subterms of myelination

# %%
sorted(id_to_name[subterm] for subterm in nx.ancestors(graph, 'GO:0042552'))

# %% [markdown]
# ### Find all paths to the root

# %%
paths = nx.all_simple_paths(
    graph,
    source=name_to_id['starch binding'],
    target=name_to_id['molecular_function']
)
for path in paths:
    print('•', ' ⟶ '.join(id_to_name[node] for node in path))

# %% [markdown]
# ### See the ontology metadata

# %%
graph.graph

# %% [markdown]
# ## SPARQL on owl with IRI
